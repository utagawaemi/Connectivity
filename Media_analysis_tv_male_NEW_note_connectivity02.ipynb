# %%
# %matplotlib inline

import os.path as op
import numpy as np
import matplotlib.pyplot as plt
from scipy import linalg

import mne
from mne.time_frequency import tfr_morlet, psd_multitaper
from mne.connectivity import spectral_connectivity

import csv

# %%
data_path = '/Users/emi/Desktop/media_TBS/mod_tv/'
cname = 'male'
sname = '01_tv_mod'
hname =  '.set'
fname = data_path + cname + sname + hname  #file nameを作る、という意味
fname     
save_path = '/Users/emi/Desktop/media_TBS/connectivity2_NEW/'

# %%
mon = mne.channels.read_montage(kind = 'standard_1020') 
aw = mne.io.read_epochs_eeglab(fname,montage=mon,
                                  eog=('EOG1', 'EOG2'))
aw.set_channel_types({'EOG1': 'eog', 'EOG2': 'eog'}) # Set Channel Type(それぞれを区別、名前をつける)
aw.set_eeg_reference('average',projection=True)
# Out:
# Extracting parameters from /Users/emi/Desktop/media_TBS/mod_tv/male01_tv_mod.set...
# <ipython-input-3-12ff945badfe>:3: RuntimeWarning: The following EEG sensors did not have a position specified in the selected montage: [u'EOG1', u'EOG2']. Their position has been left untouched.
#   eog=('EOG1', 'EOG2'))
# 25 matching events found
# No baseline correction applied
# Not setting metadata
# 0 projection items activated
# Ready.
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# <EpochsEEGLAB  |   25 events (all good), 0 - 59.999 sec, baseline off, ~343.4 MB, data loaded,
#  u'TV1': 1
#  u'TV10': 1
#  u'TV11': 1
#  u'TV12': 1
#  u'TV13': 1
#  u'TV14': 1
#  u'TV15': 1
#  u'TV16': 1
#  u'TV17': 1
#  u'TV18': 1
#  u'TV19': 1
#  u'TV2': 1
#  u'TV20': 1
#  u'TV21': 1
#  u'TV22': 1
#  u'TV23': 1
#  u'TV24': 1
#  u'TV25': 1
#  u'TV3': 1
#  u'TV4': 1
#  u'TV5': 1
#  u'TV6': 1
#  u'TV7': 1
#  u'TV8': 1
#  u'TV9': 1>

# %%
    picks = mne.pick_types(aw.info, meg=False, eeg=True, eog=False, stim=False)  #読み込むチャンネルを設定
    
    aw_S1 = aw['TV1']
    aw_S2 = aw['TV2']
    aw_S3 = aw['TV3']
    aw_S4 = aw['TV4']
    aw_S5 = aw['TV5']
    aw_S6 = aw['TV6']
    aw_S7 = aw['TV7']
    aw_S8 = aw['TV8']
    aw_S9 = aw['TV9']
    aw_S10 = aw['TV10']
    aw_S11 = aw['TV11']
    aw_S12 = aw['TV12']
    aw_S13 = aw['TV13']
    aw_S14 = aw['TV14']
    aw_S15 = aw['TV15']
    aw_S16 = aw['TV16']
    aw_S17 = aw['TV17']
    aw_S18 = aw['TV18']
    aw_S19 = aw['TV19']
    aw_S20 = aw['TV20']
    aw_S21 = aw['TV21']
    aw_S22 = aw['TV22']
    aw_S23 = aw['TV23']
    aw_S24 = aw['TV24']
    aw_S25 = aw['TV25']
    aw_S26 = aw['TV26']
    aw_S27 = aw['TV27']
    aw_S28 = aw['TV28']
    aw_S29 = aw['TV29']
    aw_S30 = aw['TV30']
    aw_S31 = aw['TV31']
    aw_S32 = aw['TV32']
    aw_S33 = aw['TV33']
    aw_S34 = aw['TV34']
    aw_S35 = aw['TV35']
    aw_S36 = aw['TV36']
    aw_S37 = aw['TV37']
    aw_S38 = aw['TV38']
    aw_S39 = aw['TV39']
    aw_S40 = aw['TV40']

    
    #### theta波 4-7Hz : Baseline
    fmin, fmax = 4., 7.
    sfreq1 = aw_S1.info['sfreq'] 
    
    
    tmin = 0  # exclude the baseline period
    tmax = 600
    con, freqs, times, n_epochs, n_tapers = spectral_connectivity(
         aw_S1, method='wpli2_debiased', mode='multitaper', sfreq=sfreq1, fmin=fmin, fmax=fmax,
         faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
    
    fname_souce = save_path + cname + sname + '_theta01-con.csv'
    with open(fname_souce, 'w') as f:
        writer = csv.writer(f, lineterminator='\n') # 改行コード（\n）を指定しておく
        writer.writerows(con[:28,:28,0]) # 2次元配列も書き込める
     
    sfreq2 = aw_S2.info['sfreq'] 

    tmin = 0  # exclude the baseline period
    tmax = 600
    con, freqs, times, n_epochs, n_tapers = spectral_connectivity(
         aw_S2, method='wpli2_debiased', mode='multitaper', sfreq=sfreq2, fmin=fmin, fmax=fmax,
         faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
    
    fname_souce = save_path + cname + sname + '_theta02-con.csv'
    with open(fname_souce, 'w') as f:
        writer = csv.writer(f, lineterminator='\n') # 改行コード（\n）を指定しておく
        writer.writerows(con[:28,:28,0]) # 2次元配列も書き込める

    sfreq3 = aw_S3.info['sfreq']         
        
    tmin = 0  # exclude the baseline period
    tmax = 600
    con, freqs, times, n_epochs, n_tapers = spectral_connectivity(
         aw_S3, method='wpli2_debiased', mode='multitaper', sfreq=sfreq3, fmin=fmin, fmax=fmax,
         faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
    
    fname_souce = save_path + cname + sname + '_theta03-con.csv'
    with open(fname_souce, 'w') as f:
        writer = csv.writer(f, lineterminator='\n') # 改行コード（\n）を指定しておく
        writer.writerows(con[:28,:28,0]) # 2次元配列も書き込める
        
    sfreq4 = aw_S4.info['sfreq']                 

    tmin = 0  # exclude the baseline period
    tmax = 600
    con, freqs, times, n_epochs, n_tapers = spectral_connectivity(
         aw_S4 method='wpli2_debiased', mode='multitaper', sfreq=sfreq4, fmin=fmin, fmax=fmax,
         faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
    
    fname_souce = save_path + cname + sname + '_theta04-con.csv'
    with open(fname_souce, 'w') as f:
        writer = csv.writer(f, lineterminator='\n') # 改行コード（\n）を指定しておく
        writer.writerows(con[:28,:28,0]) # 2次元配列も書き込める

    sfreq5 = aw_S5.info['sfreq']                 
        
    tmin = 0  # exclude the baseline period
    tmax = 600
    con, freqs, times, n_epochs, n_tapers = spectral_connectivity(
         aw_S5, method='wpli2_debiased', mode='multitaper', sfreq=sfreq5, fmin=fmin, fmax=fmax,
         faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
    
    fname_souce = save_path + cname + sname + '_theta05-con.csv'
    with open(fname_souce, 'w') as f:
        writer = csv.writer(f, lineterminator='\n') # 改行コード（\n）を指定しておく
        writer.writerows(con[:28,:28,0]) # 2次元配列も書き込める

    sfreq6 = aw_S6.info['sfreq']         
    
    tmin = 0  # exclude the baseline period
    tmax = 600
    con, freqs, times, n_epochs, n_tapers = spectral_connectivity(
         aw_S6, method='wpli2_debiased', mode='multitaper', sfreq=sfreq6, fmin=fmin, fmax=fmax,
         faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
    
    fname_souce = save_path + cname + sname + '_theta06-con.csv'
    with open(fname_souce, 'w') as f:
        writer = csv.writer(f, lineterminator='\n') # 改行コード（\n）を指定しておく
        writer.writerows(con[:28,:28,0]) # 2次元配列も書き込める

    sfreq7 = aw_S7.info['sfreq']                 
        
    tmin = 0  # exclude the baseline period
    tmax = 600
    con, freqs, times, n_epochs, n_tapers = spectral_connectivity(
         aw_S7, method='wpli2_debiased', mode='multitaper', sfreq=sfreq7, fmin=fmin, fmax=fmax,
         faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
    
    fname_souce = save_path + cname + sname + '_theta07-con.csv'
    with open(fname_souce, 'w') as f:
        writer = csv.writer(f, lineterminator='\n') # 改行コード（\n）を指定しておく
        writer.writerows(con[:28,:28,0]) # 2次元配列も書き込める

    sfreq8 = aw_S8.info['sfreq']         
        
    tmin = 0  # exclude the baseline period
    tmax = 600
    con, freqs, times, n_epochs, n_tapers = spectral_connectivity(
         aw_S8, method='wpli2_debiased', mode='multitaper', sfreq=sfreq8, fmin=fmin, fmax=fmax,
         faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
    
    fname_souce = save_path + cname + sname + '_theta08-con.csv'
    with open(fname_souce, 'w') as f:
        writer = csv.writer(f, lineterminator='\n') # 改行コード（\n）を指定しておく
        writer.writerows(con[:28,:28,0]) # 2次元配列も書き込める

    sfreq9 = aw_S9.info['sfreq']         
        
    tmin = 0  # exclude the baseline period
    tmax = 600
    con, freqs, times, n_epochs, n_tapers = spectral_connectivity(
         aw_S9, method='wpli2_debiased', mode='multitaper', sfreq=sfreq9, fmin=fmin, fmax=fmax,
         faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
    
    fname_souce = save_path + cname + sname + '_theta09-con.csv'
    with open(fname_souce, 'w') as f:
        writer = csv.writer(f, lineterminator='\n') # 改行コード（\n）を指定しておく
        writer.writerows(con[:28,:28,0]) # 2次元配列も書き込める

    sfreq10 = aw_S10.info['sfreq']         
      
        
    tmin = 0  # exclude the baseline period
    tmax = 600
    con, freqs, times, n_epochs, n_tapers = spectral_connectivity(
         aw_S10, method='wpli2_debiased', mode='multitaper', sfreq=sfreq10, fmin=fmin, fmax=fmax,
         faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
    
    fname_souce = save_path + cname + sname + '_theta10-con.csv'
    with open(fname_souce, 'w') as f:
        writer = csv.writer(f, lineterminator='\n') # 改行コード（\n）を指定しておく
        writer.writerows(con[:28,:28,0]) # 2次元配列も書き込める

    sfreq11 = aw_S11.info['sfreq']         
        
        
    tmin = 0  # exclude the baseline period
    tmax = 600
    con, freqs, times, n_epochs, n_tapers = spectral_connectivity(
         aw_S11, method='wpli2_debiased', mode='multitaper', sfreq=sfreq11, fmin=fmin, fmax=fmax,
         faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
    
    fname_souce = save_path + cname + sname + '_theta11-con.csv'
    with open(fname_souce, 'w') as f:
        writer = csv.writer(f, lineterminator='\n') # 改行コード（\n）を指定しておく
        writer.writerows(con[:28,:28,0]) # 2次元配列も書き込める

        sfreq12 = aw_S12.info['sfreq']         
        
        
    tmin = 0  # exclude the baseline period
    tmax = 600
    con, freqs, times, n_epochs, n_tapers = spectral_connectivity(
         aw_S12, method='wpli2_debiased', mode='multitaper', sfreq=sfreq12, fmin=fmin, fmax=fmax,
         faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
    
    fname_souce = save_path + cname + sname + '_theta12-con.csv'
    with open(fname_souce, 'w') as f:
        writer = csv.writer(f, lineterminator='\n') # 改行コード（\n）を指定しておく
        writer.writerows(con[:28,:28,0]) # 2次元配列も書き込める

    sfreq13 = aw_S13.info['sfreq']         
       
        
    tmin = 0  # exclude the baseline period
    tmax = 600
    con, freqs, times, n_epochs, n_tapers = spectral_connectivity(
         aw_S13, method='wpli2_debiased', mode='multitaper', sfreq=sfreq13, fmin=fmin, fmax=fmax,
         faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
    
    fname_souce = save_path + cname + sname + '_theta13-con.csv'
    with open(fname_souce, 'w') as f:
        writer = csv.writer(f, lineterminator='\n') # 改行コード（\n）を指定しておく
        writer.writerows(con[:28,:28,0]) # 2次元配列も書き込める
        
    sfreq14 = aw_S14.info['sfreq']         
        
    tmin = 0  # exclude the baseline period
    tmax = 600
    con, freqs, times, n_epochs, n_tapers = spectral_connectivity(
         aw_S14, method='wpli2_debiased', mode='multitaper', sfreq=sfreq14, fmin=fmin, fmax=fmax,
         faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
    
    fname_souce = save_path + cname + sname + '_theta14-con.csv'
    with open(fname_souce, 'w') as f:
        writer = csv.writer(f, lineterminator='\n') # 改行コード（\n）を指定しておく
        writer.writerows(con[:28,:28,0]) # 2次元配列も書き込める

    sfreq15 = aw_S15.info['sfreq']         
        
    tmin = 0  # exclude the baseline period
    tmax = 600
    con, freqs, times, n_epochs, n_tapers = spectral_connectivity(
         aw_S15, method='wpli2_debiased', mode='multitaper', sfreq=sfreq15, fmin=fmin, fmax=fmax,
         faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
    
    fname_souce = save_path + cname + sname + '_theta15-con.csv'
    with open(fname_souce, 'w') as f:
        writer = csv.writer(f, lineterminator='\n') # 改行コード（\n）を指定しておく
        writer.writerows(con[:28,:28,0]) # 2次元配列も書き込める

        sfreq16 = aw_S16.info['sfreq']         
        
        
    tmin = 0  # exclude the baseline period
    tmax = 600
    con, freqs, times, n_epochs, n_tapers = spectral_connectivity(
         aw_S16, method='wpli2_debiased', mode='multitaper', sfreq=sfreq16, fmin=fmin, fmax=fmax,
         faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
    
    fname_souce = save_path + cname + sname + '_theta16-con.csv'
    with open(fname_souce, 'w') as f:
        writer = csv.writer(f, lineterminator='\n') # 改行コード（\n）を指定しておく
        writer.writerows(con[:28,:28,0]) # 2次元配列も書き込める

    sfreq17 = aw_S17.info['sfreq']         
        
    tmin = 0  # exclude the baseline period
    tmax = 600
    con, freqs, times, n_epochs, n_tapers = spectral_connectivity(
         aw_S17, method='wpli2_debiased', mode='multitaper', sfreq=sfreq17, fmin=fmin, fmax=fmax,
         faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
    
    fname_souce = save_path + cname + sname + '_theta17-con.csv'
    with open(fname_souce, 'w') as f:
        writer = csv.writer(f, lineterminator='\n') # 改行コード（\n）を指定しておく
        writer.writerows(con[:28,:28,0]) # 2次元配列も書き込める

    sfreq18 = aw_S18.info['sfreq']         
        
    tmin = 0  # exclude the baseline period
    tmax = 600
    con, freqs, times, n_epochs, n_tapers = spectral_connectivity(
         aw_S18, method='wpli2_debiased', mode='multitaper', sfreq=sfreq18, fmin=fmin, fmax=fmax,
         faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
    
    fname_souce = save_path + cname + sname + '_theta18-con.csv'
    with open(fname_souce, 'w') as f:
        writer = csv.writer(f, lineterminator='\n') # 改行コード（\n）を指定しておく
        writer.writerows(con[:28,:28,0]) # 2次元配列も書き込める

    sfreq19 = aw_S19.info['sfreq']                     
        
    tmin = 0  # exclude the baseline period
    tmax = 600
    con, freqs, times, n_epochs, n_tapers = spectral_connectivity(
         aw_S19, method='wpli2_debiased', mode='multitaper', sfreq=sfreq19, fmin=fmin, fmax=fmax,
         faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
    
    fname_souce = save_path + cname + sname + '_theta19-con.csv'
    with open(fname_souce, 'w') as f:
        writer = csv.writer(f, lineterminator='\n') # 改行コード（\n）を指定しておく
        writer.writerows(con[:28,:28,0]) # 2次元配列も書き込める

    sfreq20 = aw_S20.info['sfreq']             
        
    tmin = 0  # exclude the baseline period
    tmax = 600
    con, freqs, times, n_epochs, n_tapers = spectral_connectivity(
         aw_S20, method='wpli2_debiased', mode='multitaper', sfreq=sfreq20, fmin=fmin, fmax=fmax,
         faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
    
    fname_souce = save_path + cname + sname + '_theta20-con.csv'
    with open(fname_souce, 'w') as f:
        writer = csv.writer(f, lineterminator='\n') # 改行コード（\n）を指定しておく
        writer.writerows(con[:28,:28,0]) # 2次元配列も書き込める
 
    sfreq21 = aw_S21.info['sfreq']             

    tmin = 0  # exclude the baseline period
    tmax = 600
    con, freqs, times, n_epochs, n_tapers = spectral_connectivity(
         aw_S21, method='wpli2_debiased', mode='multitaper', sfreq=sfreq21, fmin=fmin, fmax=fmax,
         faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
    
    fname_souce = save_path + cname + sname + '_theta21-con.csv'
    with open(fname_souce, 'w') as f:
        writer = csv.writer(f, lineterminator='\n') # 改行コード（\n）を指定しておく
        writer.writerows(con[:28,:28,0]) # 2次元配列も書き込める

    sfreq22 = aw_S22.info['sfreq']             

    tmin = 0  # exclude the baseline period
    tmax = 600
    con, freqs, times, n_epochs, n_tapers = spectral_connectivity(
         aw_S22, method='wpli2_debiased', mode='multitaper', sfreq=sfreq22, fmin=fmin, fmax=fmax,
         faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
    
    fname_souce = save_path + cname + sname + '_theta22-con.csv'
    with open(fname_souce, 'w') as f:
        writer = csv.writer(f, lineterminator='\n') # 改行コード（\n）を指定しておく
        writer.writerows(con[:28,:28,0]) # 2次元配列も書き込める

    sfreq23 = aw_S23.info['sfreq']             
        
    tmin = 0  # exclude the baseline period
    tmax = 600
    con, freqs, times, n_epochs, n_tapers = spectral_connectivity(
         aw_S23, method='wpli2_debiased', mode='multitaper', sfreq=sfreq23, fmin=fmin, fmax=fmax,
         faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
    
    fname_souce = save_path + cname + sname + '_theta23-con.csv'
    with open(fname_souce, 'w') as f:
        writer = csv.writer(f, lineterminator='\n') # 改行コード（\n）を指定しておく
        writer.writerows(con[:28,:28,0]) # 2次元配列も書き込める

    sfreq24 = aw_S24.info['sfreq']             
        
    tmin = 0  # exclude the baseline period
    tmax = 600
    con, freqs, times, n_epochs, n_tapers = spectral_connectivity(
         aw_S24, method='wpli2_debiased', mode='multitaper', sfreq=sfreq24, fmin=fmin, fmax=fmax,
         faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
    
    fname_souce = save_path + cname + sname + '_theta24-con.csv'
    with open(fname_souce, 'w') as f:
        writer = csv.writer(f, lineterminator='\n') # 改行コード（\n）を指定しておく
        writer.writerows(con[:28,:28,0]) # 2次元配列も書き込める

    sfreq25 = aw_S25.info['sfreq']             
        
    tmin = 0  # exclude the baseline period
    tmax = 600
    con, freqs, times, n_epochs, n_tapers = spectral_connectivity(
         aw_S25, method='wpli2_debiased', mode='multitaper', sfreq=sfreq25, fmin=fmin, fmax=fmax,
         faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
    
    fname_souce = save_path + cname + sname + '_theta25-con.csv'
    with open(fname_souce, 'w') as f:
        writer = csv.writer(f, lineterminator='\n') # 改行コード（\n）を指定しておく
        writer.writerows(con[:28,:28,0]) # 2次元配列も書き込める

    sfreq26 = aw_S26.info['sfreq']             

    tmin = 0  # exclude the baseline period
    tmax = 600
    con, freqs, times, n_epochs, n_tapers = spectral_connectivity(
         aw_S26, method='wpli2_debiased', mode='multitaper', sfreq=sfreq26, fmin=fmin, fmax=fmax,
         faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
    
    fname_souce = save_path + cname + sname + '_theta26-con.csv'
    with open(fname_souce, 'w') as f:
        writer = csv.writer(f, lineterminator='\n') # 改行コード（\n）を指定しておく
        writer.writerows(con[:28,:28,0]) # 2次元配列も書き込める

    sfreq27 = aw_S27.info['sfreq']             
        
    tmin = 0  # exclude the baseline period
    tmax = 600
    con, freqs, times, n_epochs, n_tapers = spectral_connectivity(
         aw_S27, method='wpli2_debiased', mode='multitaper', sfreq=sfreq27, fmin=fmin, fmax=fmax,
         faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
    
    fname_souce = save_path + cname + sname + '_theta27-con.csv'
    with open(fname_souce, 'w') as f:
        writer = csv.writer(f, lineterminator='\n') # 改行コード（\n）を指定しておく
        writer.writerows(con[:28,:28,0]) # 2次元配列も書き込める

    sfreq28 = aw_S28.info['sfreq']             
        
    tmin = 0  # exclude the baseline period
    tmax = 600
    con, freqs, times, n_epochs, n_tapers = spectral_connectivity(
         aw_S28, method='wpli2_debiased', mode='multitaper', sfreq=sfreq28, fmin=fmin, fmax=fmax,
         faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
    
    fname_souce = save_path + cname + sname + '_theta28-con.csv'
    with open(fname_souce, 'w') as f:
        writer = csv.writer(f, lineterminator='\n') # 改行コード（\n）を指定しておく
        writer.writerows(con[:28,:28,0]) # 2次元配列も書き込める

    sfreq29 = aw_S29.info['sfreq']             
        
    tmin = 0  # exclude the baseline period
    tmax = 600
    con, freqs, times, n_epochs, n_tapers = spectral_connectivity(
         aw_S29, method='wpli2_debiased', mode='multitaper', sfreq=sfreq29, fmin=fmin, fmax=fmax,
         faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
    
    fname_souce = save_path + cname + sname + '_theta29-con.csv'
    with open(fname_souce, 'w') as f:
        writer = csv.writer(f, lineterminator='\n') # 改行コード（\n）を指定しておく
        writer.writerows(con[:28,:28,0]) # 2次元配列も書き込める

    sfreq30 = aw_S30.info['sfreq']             
        
    tmin = 0  # exclude the baseline period
    tmax = 600
    con, freqs, times, n_epochs, n_tapers = spectral_connectivity(
         aw_S30, method='wpli2_debiased', mode='multitaper', sfreq=sfreq30, fmin=fmin, fmax=fmax,
         faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
    
    fname_souce = save_path + cname + sname + '_theta30-con.csv'
    with open(fname_souce, 'w') as f:
        writer = csv.writer(f, lineterminator='\n') # 改行コード（\n）を指定しておく
        writer.writerows(con[:28,:28,0]) # 2次元配列も書き込める

    sfreq31 = aw_S31.info['sfreq']             
       
    tmin = 0  # exclude the baseline period
    tmax = 600
    con, freqs, times, n_epochs, n_tapers = spectral_connectivity(
         aw_S31, method='wpli2_debiased', mode='multitaper', sfreq=sfreq31, fmin=fmin, fmax=fmax,
         faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
    
    fname_souce = save_path + cname + sname + '_theta31-con.csv'
    with open(fname_souce, 'w') as f:
        writer = csv.writer(f, lineterminator='\n') # 改行コード（\n）を指定しておく
        writer.writerows(con[:28,:28,0]) # 2次元配列も書き込める

    sfreq32 = aw_S32.info['sfreq']             

    tmin = 0  # exclude the baseline period
    tmax = 600
    con, freqs, times, n_epochs, n_tapers = spectral_connectivity(
         aw_S32, method='wpli2_debiased', mode='multitaper', sfreq=sfreq32, fmin=fmin, fmax=fmax,
         faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
    
    fname_souce = save_path + cname + sname + '_theta32-con.csv'
    with open(fname_souce, 'w') as f:
        writer = csv.writer(f, lineterminator='\n') # 改行コード（\n）を指定しておく
        writer.writerows(con[:28,:28,0]) # 2次元配列も書き込める

    sfreq33 = aw_S33.info['sfreq']             

    tmin = 0  # exclude the baseline period
    tmax = 600
    con, freqs, times, n_epochs, n_tapers = spectral_connectivity(
         aw_S33, method='wpli2_debiased', mode='multitaper', sfreq=sfreq33, fmin=fmin, fmax=fmax,
         faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
    
    fname_souce = save_path + cname + sname + '_theta33-con.csv'
    with open(fname_souce, 'w') as f:
        writer = csv.writer(f, lineterminator='\n') # 改行コード（\n）を指定しておく
        writer.writerows(con[:28,:28,0]) # 2次元配列も書き込める

    sfreq34 = aw_S34.info['sfreq']             

    tmin = 0  # exclude the baseline period
    tmax = 600
    con, freqs, times, n_epochs, n_tapers = spectral_connectivity(
         aw_S34, method='wpli2_debiased', mode='multitaper', sfreq=sfreq34, fmin=fmin, fmax=fmax,
         faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
    
    fname_souce = save_path + cname + sname + '_theta34-con.csv'
    with open(fname_souce, 'w') as f:
        writer = csv.writer(f, lineterminator='\n') # 改行コード（\n）を指定しておく
        writer.writerows(con[:28,:28,0]) # 2次元配列も書き込める

    sfreq35 = aw_S35.info['sfreq']             

    tmin = 0  # exclude the baseline period
    tmax = 600
    con, freqs, times, n_epochs, n_tapers = spectral_connectivity(
         aw_S35, method='wpli2_debiased', mode='multitaper', sfreq=sfreq35, fmin=fmin, fmax=fmax,
         faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
    
    fname_souce = save_path + cname + sname + '_theta35-con.csv'
    with open(fname_souce, 'w') as f:
        writer = csv.writer(f, lineterminator='\n') # 改行コード（\n）を指定しておく
        writer.writerows(con[:28,:28,0]) # 2次元配列も書き込める

    sfreq36 = aw_S36.info['sfreq']             

    tmin = 0  # exclude the baseline period
    tmax = 600
    con, freqs, times, n_epochs, n_tapers = spectral_connectivity(
         aw_S36, method='wpli2_debiased', mode='multitaper', sfreq=sfreq36, fmin=fmin, fmax=fmax,
         faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
    
    fname_souce = save_path + cname + sname + '_theta36-con.csv'
    with open(fname_souce, 'w') as f:
        writer = csv.writer(f, lineterminator='\n') # 改行コード（\n）を指定しておく
        writer.writerows(con[:28,:28,0]) # 2次元配列も書き込める

    sfreq37 = aw_S37.info['sfreq']             

    tmin = 0  # exclude the baseline period
    tmax = 600
    con, freqs, times, n_epochs, n_tapers = spectral_connectivity(
         aw_S37, method='wpli2_debiased', mode='multitaper', sfreq=sfreq37, fmin=fmin, fmax=fmax,
         faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
    
    fname_souce = save_path + cname + sname + '_theta37-con.csv'
    with open(fname_souce, 'w') as f:
        writer = csv.writer(f, lineterminator='\n') # 改行コード（\n）を指定しておく
        writer.writerows(con[:28,:28,0]) # 2次元配列も書き込める

    sfreq38 = aw_S38.info['sfreq']             

    tmin = 0  # exclude the baseline period
    tmax = 600
    con, freqs, times, n_epochs, n_tapers = spectral_connectivity(
         aw_S38, method='wpli2_debiased', mode='multitaper', sfreq=sfreq38, fmin=fmin, fmax=fmax,
         faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
    
    fname_souce = save_path + cname + sname + '_theta38-con.csv'
    with open(fname_souce, 'w') as f:
        writer = csv.writer(f, lineterminator='\n') # 改行コード（\n）を指定しておく
        writer.writerows(con[:28,:28,0]) # 2次元配列も書き込める

    sfreq39 = aw_S39.info['sfreq']    
    
    tmin = 0  # exclude the baseline period
    tmax = 600
    con, freqs, times, n_epochs, n_tapers = spectral_connectivity(
         aw_S39, method='wpli2_debiased', mode='multitaper', sfreq=sfreq39, fmin=fmin, fmax=fmax,
         faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
    
    fname_souce = save_path + cname + sname + '_theta39-con.csv'
    with open(fname_souce, 'w') as f:
        writer = csv.writer(f, lineterminator='\n') # 改行コード（\n）を指定しておく
        writer.writerows(con[:28,:28,0]) # 2次元配列も書き込める

    sfreq40 = aw_S40.info['sfreq']    
    
    tmin = 0  # exclude the baseline period
    tmax = 600
    con, freqs, times, n_epochs, n_tapers = spectral_connectivity(
         aw_S40, method='wpli2_debiased', mode='multitaper', sfreq=sfreq40, fmin=fmin, fmax=fmax,
         faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
    
    fname_souce = save_path + cname + sname + '_theta40-con.csv'
    with open(fname_souce, 'w') as f:
        writer = csv.writer(f, lineterminator='\n') # 改行コード（\n）を指定しておく
        writer.writerows(con[:28,:28,0]) # 2次元配列も書き込める
# Out:
#   File "<ipython-input-4-ff5009fed5f2>", line 92
#     aw_S4 method='wpli2_debiased', mode='multitaper', sfreq=sfreq4, fmin=fmin, fmax=fmax,
#                ^
# SyntaxError: invalid syntax

# %%
        # ### alpha波 4-7Hz : Baseline
    
    fmin, fmax = 8., 13.
    sfreq = aw_S1.info['sfreq']  # the sampling frequency
    
    
    tmin = 0  # exclude the baseline period
    tmax = 600
    con, freqs, times, n_epochs, n_tapers = spectral_connectivity(
         aw_S1, method='wpli2_debiased', mode='multitaper', sfreq=sfreq, fmin=fmin, fmax=fmax,
         faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
    
    fname_souce = save_path + cname + sname + '_alpha01-con.csv'
    with open(fname_souce, 'w') as f:
        writer = csv.writer(f, lineterminator='\n') # 改行コード（\n）を指定しておく
        writer.writerows(con[:28,:28,0]) # 2次元配列も書き込める
        
    tmin = 0  # exclude the baseline period
    tmax = 600
    con, freqs, times, n_epochs, n_tapers = spectral_connectivity(
         aw_S2, method='wpli2_debiased', mode='multitaper', sfreq=sfreq, fmin=fmin, fmax=fmax,
         faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
    
    fname_souce = save_path + cname + sname + '_alpha02-con.csv'
    with open(fname_souce, 'w') as f:
        writer = csv.writer(f, lineterminator='\n') # 改行コード（\n）を指定しておく
        writer.writerows(con[:28,:28,0]) # 2次元配列も書き込める

    tmin = 0  # exclude the baseline period
    tmax = 600
    con, freqs, times, n_epochs, n_tapers = spectral_connectivity(
         aw_S3, method='wpli2_debiased', mode='multitaper', sfreq=sfreq, fmin=fmin, fmax=fmax,
         faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
    
    fname_souce = save_path + cname + sname + '_alpha03-con.csv'
    with open(fname_souce, 'w') as f:
        writer = csv.writer(f, lineterminator='\n') # 改行コード（\n）を指定しておく
        writer.writerows(con[:28,:28,0]) # 2次元配列も書き込める
        
    tmin = 0  # exclude the baseline period
    tmax = 600
    con, freqs, times, n_epochs, n_tapers = spectral_connectivity(
         aw_S4, method='wpli2_debiased', mode='multitaper', sfreq=sfreq, fmin=fmin, fmax=fmax,
         faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
    
    fname_souce = save_path + cname + sname + '_alpha04-con.csv'
    with open(fname_souce, 'w') as f:
        writer = csv.writer(f, lineterminator='\n') # 改行コード（\n）を指定しておく
        writer.writerows(con[:28,:28,0]) # 2次元配列も書き込める
        
    tmin = 0  # exclude the baseline period
    tmax = 600
    con, freqs, times, n_epochs, n_tapers = spectral_connectivity(
         aw_S5, method='wpli2_debiased', mode='multitaper', sfreq=sfreq, fmin=fmin, fmax=fmax,
         faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
    
    fname_souce = save_path + cname + sname + '_alpha05-con.csv'
    with open(fname_souce, 'w') as f:
        writer = csv.writer(f, lineterminator='\n') # 改行コード（\n）を指定しておく
        writer.writerows(con[:28,:28,0]) # 2次元配列も書き込める

    tmin = 0  # exclude the baseline period
    tmax = 600
    con, freqs, times, n_epochs, n_tapers = spectral_connectivity(
         aw_S6, method='wpli2_debiased', mode='multitaper', sfreq=sfreq, fmin=fmin, fmax=fmax,
         faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
    
    fname_souce = save_path + cname + sname + '_alpha06-con.csv'
    with open(fname_souce, 'w') as f:
        writer = csv.writer(f, lineterminator='\n') # 改行コード（\n）を指定しておく
        writer.writerows(con[:28,:28,0]) # 2次元配列も書き込める
        
    tmin = 0  # exclude the baseline period
    tmax = 600
    con, freqs, times, n_epochs, n_tapers = spectral_connectivity(
         aw_S7, method='wpli2_debiased', mode='multitaper', sfreq=sfreq, fmin=fmin, fmax=fmax,
         faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
    
    fname_souce = save_path + cname + sname + '_alpha07-con.csv'
    with open(fname_souce, 'w') as f:
        writer = csv.writer(f, lineterminator='\n') # 改行コード（\n）を指定しておく
        writer.writerows(con[:28,:28,0]) # 2次元配列も書き込める
        
    tmin = 0  # exclude the baseline period
    tmax = 600
    con, freqs, times, n_epochs, n_tapers = spectral_connectivity(
         aw_S8, method='wpli2_debiased', mode='multitaper', sfreq=sfreq, fmin=fmin, fmax=fmax,
         faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
    
    fname_souce = save_path + cname + sname + '_alpha08-con.csv'
    with open(fname_souce, 'w') as f:
        writer = csv.writer(f, lineterminator='\n') # 改行コード（\n）を指定しておく
        writer.writerows(con[:28,:28,0]) # 2次元配列も書き込める

    tmin = 0  # exclude the baseline period
    tmax = 600
    con, freqs, times, n_epochs, n_tapers = spectral_connectivity(
         aw_S9, method='wpli2_debiased', mode='multitaper', sfreq=sfreq, fmin=fmin, fmax=fmax,
         faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
    
    fname_souce = save_path + cname + sname + '_alpha09-con.csv'
    with open(fname_souce, 'w') as f:
        writer = csv.writer(f, lineterminator='\n') # 改行コード（\n）を指定しておく
        writer.writerows(con[:28,:28,0]) # 2次元配列も書き込める
        
    tmin = 0  # exclude the baseline period
    tmax = 600
    con, freqs, times, n_epochs, n_tapers = spectral_connectivity(
         aw_S10, method='wpli2_debiased', mode='multitaper', sfreq=sfreq, fmin=fmin, fmax=fmax,
         faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
    
    fname_souce = save_path + cname + sname + '_alpha10-con.csv'
    with open(fname_souce, 'w') as f:
        writer = csv.writer(f, lineterminator='\n') # 改行コード（\n）を指定しておく
        writer.writerows(con[:28,:28,0]) # 2次元配列も書き込める
        
    tmin = 0  # exclude the baseline period
    tmax = 600
    con, freqs, times, n_epochs, n_tapers = spectral_connectivity(
         aw_S11, method='wpli2_debiased', mode='multitaper', sfreq=sfreq, fmin=fmin, fmax=fmax,
         faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
    
    fname_souce = save_path + cname + sname + '_alpha11-con.csv'
    with open(fname_souce, 'w') as f:
        writer = csv.writer(f, lineterminator='\n') # 改行コード（\n）を指定しておく
        writer.writerows(con[:28,:28,0]) # 2次元配列も書き込める

    tmin = 0  # exclude the baseline period
    tmax = 600
    con, freqs, times, n_epochs, n_tapers = spectral_connectivity(
         aw_S12, method='wpli2_debiased', mode='multitaper', sfreq=sfreq, fmin=fmin, fmax=fmax,
         faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
    
    fname_souce = save_path + cname + sname + '_alpha12-con.csv'
    with open(fname_souce, 'w') as f:
        writer = csv.writer(f, lineterminator='\n') # 改行コード（\n）を指定しておく
        writer.writerows(con[:28,:28,0]) # 2次元配列も書き込める
        
    tmin = 0  # exclude the baseline period
    tmax = 600
    con, freqs, times, n_epochs, n_tapers = spectral_connectivity(
         aw_S13, method='wpli2_debiased', mode='multitaper', sfreq=sfreq, fmin=fmin, fmax=fmax,
         faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
    
    fname_souce = save_path + cname + sname + '_alpha13-con.csv'
    with open(fname_souce, 'w') as f:
        writer = csv.writer(f, lineterminator='\n') # 改行コード（\n）を指定しておく
        writer.writerows(con[:28,:28,0]) # 2次元配列も書き込める
        
        
    tmin = 0  # exclude the baseline period
    tmax = 600
    con, freqs, times, n_epochs, n_tapers = spectral_connectivity(
         aw_S14, method='wpli2_debiased', mode='multitaper', sfreq=sfreq, fmin=fmin, fmax=fmax,
         faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
    
    fname_souce = save_path + cname + sname + '_alpha14-con.csv'
    with open(fname_souce, 'w') as f:
        writer = csv.writer(f, lineterminator='\n') # 改行コード（\n）を指定しておく
        writer.writerows(con[:28,:28,0]) # 2次元配列も書き込める
        
    tmin = 0  # exclude the baseline period
    tmax = 600
    con, freqs, times, n_epochs, n_tapers = spectral_connectivity(
         aw_S15, method='wpli2_debiased', mode='multitaper', sfreq=sfreq, fmin=fmin, fmax=fmax,
         faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
    
    fname_souce = save_path + cname + sname + '_alpha15-con.csv'
    with open(fname_souce, 'w') as f:
        writer = csv.writer(f, lineterminator='\n') # 改行コード（\n）を指定しておく
        writer.writerows(con[:28,:28,0]) # 2次元配列も書き込める

    tmin = 0  # exclude the baseline period
    tmax = 600
    con, freqs, times, n_epochs, n_tapers = spectral_connectivity(
         aw_S16, method='wpli2_debiased', mode='multitaper', sfreq=sfreq, fmin=fmin, fmax=fmax,
         faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
    
    fname_souce = save_path + cname + sname + '_alpha16-con.csv'
    with open(fname_souce, 'w') as f:
        writer = csv.writer(f, lineterminator='\n') # 改行コード（\n）を指定しておく
        writer.writerows(con[:28,:28,0]) # 2次元配列も書き込める
        
    tmin = 0  # exclude the baseline period
    tmax = 600
    con, freqs, times, n_epochs, n_tapers = spectral_connectivity(
         aw_S17, method='wpli2_debiased', mode='multitaper', sfreq=sfreq, fmin=fmin, fmax=fmax,
         faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
    
    fname_souce = save_path + cname + sname + '_alpha17-con.csv'
    with open(fname_souce, 'w') as f:
        writer = csv.writer(f, lineterminator='\n') # 改行コード（\n）を指定しておく
        writer.writerows(con[:28,:28,0]) # 2次元配列も書き込める
        
    tmin = 0  # exclude the baseline period
    tmax = 600
    con, freqs, times, n_epochs, n_tapers = spectral_connectivity(
         aw_S18, method='wpli2_debiased', mode='multitaper', sfreq=sfreq, fmin=fmin, fmax=fmax,
         faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
    
    fname_souce = save_path + cname + sname + '_alpha18-con.csv'
    with open(fname_souce, 'w') as f:
        writer = csv.writer(f, lineterminator='\n') # 改行コード（\n）を指定しておく
        writer.writerows(con[:28,:28,0]) # 2次元配列も書き込める

    tmin = 0  # exclude the baseline period
    tmax = 600
    con, freqs, times, n_epochs, n_tapers = spectral_connectivity(
         aw_S19, method='wpli2_debiased', mode='multitaper', sfreq=sfreq, fmin=fmin, fmax=fmax,
         faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
    
    fname_souce = save_path + cname + sname + '_alpha19-con.csv'
    with open(fname_souce, 'w') as f:
        writer = csv.writer(f, lineterminator='\n') # 改行コード（\n）を指定しておく
        writer.writerows(con[:28,:28,0]) # 2次元配列も書き込める
        
    tmin = 0  # exclude the baseline period
    tmax = 600
    con, freqs, times, n_epochs, n_tapers = spectral_connectivity(
         aw_S20, method='wpli2_debiased', mode='multitaper', sfreq=sfreq, fmin=fmin, fmax=fmax,
         faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
    
    fname_souce = save_path + cname + sname + '_alpha20-con.csv'
    with open(fname_souce, 'w') as f:
        writer = csv.writer(f, lineterminator='\n') # 改行コード（\n）を指定しておく
        writer.writerows(con[:28,:28,0]) # 2次元配列も書き込める
        
    tmin = 0  # exclude the baseline period
    tmax = 600
    con, freqs, times, n_epochs, n_tapers = spectral_connectivity(
         aw_S21, method='wpli2_debiased', mode='multitaper', sfreq=sfreq, fmin=fmin, fmax=fmax,
         faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
    
    fname_souce = save_path + cname + sname + '_alpha21-con.csv'
    with open(fname_souce, 'w') as f:
        writer = csv.writer(f, lineterminator='\n') # 改行コード（\n）を指定しておく
        writer.writerows(con[:28,:28,0]) # 2次元配列も書き込める

    tmin = 0  # exclude the baseline period
    tmax = 600
    con, freqs, times, n_epochs, n_tapers = spectral_connectivity(
         aw_S22, method='wpli2_debiased', mode='multitaper', sfreq=sfreq, fmin=fmin, fmax=fmax,
         faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
    
    fname_souce = save_path + cname + sname + '_alpha22-con.csv'
    with open(fname_souce, 'w') as f:
        writer = csv.writer(f, lineterminator='\n') # 改行コード（\n）を指定しておく
        writer.writerows(con[:28,:28,0]) # 2次元配列も書き込める
        
    tmin = 0  # exclude the baseline period
    tmax = 600
    con, freqs, times, n_epochs, n_tapers = spectral_connectivity(
         aw_S23, method='wpli2_debiased', mode='multitaper', sfreq=sfreq, fmin=fmin, fmax=fmax,
         faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
    
    fname_souce = save_path + cname + sname + '_alpha23-con.csv'
    with open(fname_souce, 'w') as f:
        writer = csv.writer(f, lineterminator='\n') # 改行コード（\n）を指定しておく
        writer.writerows(con[:28,:28,0]) # 2次元配列も書き込める
        
    tmin = 0  # exclude the baseline period
    tmax = 600
    con, freqs, times, n_epochs, n_tapers = spectral_connectivity(
         aw_S24, method='wpli2_debiased', mode='multitaper', sfreq=sfreq, fmin=fmin, fmax=fmax,
         faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
    
    fname_souce = save_path + cname + sname + '_alpha24-con.csv'
    with open(fname_souce, 'w') as f:
        writer = csv.writer(f, lineterminator='\n') # 改行コード（\n）を指定しておく
        writer.writerows(con[:28,:28,0]) # 2次元配列も書き込める
        
    tmin = 0  # exclude the baseline period
    tmax = 600
    con, freqs, times, n_epochs, n_tapers = spectral_connectivity(
         aw_S25, method='wpli2_debiased', mode='multitaper', sfreq=sfreq, fmin=fmin, fmax=fmax,
         faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
    
    fname_souce = save_path + cname + sname + '_alpha25-con.csv'
    with open(fname_souce, 'w') as f:
        writer = csv.writer(f, lineterminator='\n') # 改行コード（\n）を指定しておく
        writer.writerows(con[:28,:28,0]) # 2次元配列も書き込める
        
    tmin = 0  # exclude the baseline period
    tmax = 600
    con, freqs, times, n_epochs, n_tapers = spectral_connectivity(
         aw_S26, method='wpli2_debiased', mode='multitaper', sfreq=sfreq, fmin=fmin, fmax=fmax,
         faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
    
    fname_souce = save_path + cname + sname + '_alpha26-con.csv'
    with open(fname_souce, 'w') as f:
        writer = csv.writer(f, lineterminator='\n') # 改行コード（\n）を指定しておく
        writer.writerows(con[:28,:28,0]) # 2次元配列も書き込める
        
        
    tmin = 0  # exclude the baseline period
    tmax = 600
    con, freqs, times, n_epochs, n_tapers = spectral_connectivity(
         aw_S27, method='wpli2_debiased', mode='multitaper', sfreq=sfreq, fmin=fmin, fmax=fmax,
         faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
    
    fname_souce = save_path + cname + sname + '_alpha27-con.csv'
    with open(fname_souce, 'w') as f:
        writer = csv.writer(f, lineterminator='\n') # 改行コード（\n）を指定しておく
        writer.writerows(con[:28,:28,0]) # 2次元配列も書き込める
        
    tmin = 0  # exclude the baseline period
    tmax = 600
    con, freqs, times, n_epochs, n_tapers = spectral_connectivity(
         aw_S28, method='wpli2_debiased', mode='multitaper', sfreq=sfreq, fmin=fmin, fmax=fmax,
         faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
    
    fname_souce = save_path + cname + sname + '_alpha28-con.csv'
    with open(fname_souce, 'w') as f:
        writer = csv.writer(f, lineterminator='\n') # 改行コード（\n）を指定しておく
        writer.writerows(con[:28,:28,0]) # 2次元配列も書き込める
        
    tmin = 0  # exclude the baseline period
    tmax = 600
    con, freqs, times, n_epochs, n_tapers = spectral_connectivity(
         aw_S29, method='wpli2_debiased', mode='multitaper', sfreq=sfreq, fmin=fmin, fmax=fmax,
         faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
    
    fname_souce = save_path + cname + sname + '_alpha29-con.csv'
    with open(fname_souce, 'w') as f:
        writer = csv.writer(f, lineterminator='\n') # 改行コード（\n）を指定しておく
        writer.writerows(con[:28,:28,0]) # 2次元配列も書き込める

    tmin = 0  # exclude the baseline period
    tmax = 600
    con, freqs, times, n_epochs, n_tapers = spectral_connectivity(
         aw_S30, method='wpli2_debiased', mode='multitaper', sfreq=sfreq, fmin=fmin, fmax=fmax,
         faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
    
    fname_souce = save_path + cname + sname + '_alpha30-con.csv'
    with open(fname_souce, 'w') as f:
        writer = csv.writer(f, lineterminator='\n') # 改行コード（\n）を指定しておく
        writer.writerows(con[:28,:28,0]) # 2次元配列も書き込める
        
    tmin = 0  # exclude the baseline period
    tmax = 600
    con, freqs, times, n_epochs, n_tapers = spectral_connectivity(
         aw_S31, method='wpli2_debiased', mode='multitaper', sfreq=sfreq, fmin=fmin, fmax=fmax,
         faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
    
    fname_souce = save_path + cname + sname + '_alpha31-con.csv'
    with open(fname_souce, 'w') as f:
        writer = csv.writer(f, lineterminator='\n') # 改行コード（\n）を指定しておく
        writer.writerows(con[:28,:28,0]) # 2次元配列も書き込める
        
    tmin = 0  # exclude the baseline period
    tmax = 600
    con, freqs, times, n_epochs, n_tapers = spectral_connectivity(
         aw_S32, method='wpli2_debiased', mode='multitaper', sfreq=sfreq, fmin=fmin, fmax=fmax,
         faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
    
    fname_souce = save_path + cname + sname + '_alpha32-con.csv'
    with open(fname_souce, 'w') as f:
        writer = csv.writer(f, lineterminator='\n') # 改行コード（\n）を指定しておく
        writer.writerows(con[:28,:28,0]) # 2次元配列も書き込める

    tmin = 0  # exclude the baseline period
    tmax = 600
    con, freqs, times, n_epochs, n_tapers = spectral_connectivity(
         aw_S33, method='wpli2_debiased', mode='multitaper', sfreq=sfreq, fmin=fmin, fmax=fmax,
         faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
    
    fname_souce = save_path + cname + sname + '_alpha33-con.csv'
    with open(fname_souce, 'w') as f:
        writer = csv.writer(f, lineterminator='\n') # 改行コード（\n）を指定しておく
        writer.writerows(con[:28,:28,0]) # 2次元配列も書き込める
        
    tmin = 0  # exclude the baseline period
    tmax = 600
    con, freqs, times, n_epochs, n_tapers = spectral_connectivity(
         aw_S34, method='wpli2_debiased', mode='multitaper', sfreq=sfreq, fmin=fmin, fmax=fmax,
         faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
    
    fname_souce = save_path + cname + sname + '_alpha34-con.csv'
    with open(fname_souce, 'w') as f:
        writer = csv.writer(f, lineterminator='\n') # 改行コード（\n）を指定しておく
        writer.writerows(con[:28,:28,0]) # 2次元配列も書き込める
        
    tmin = 0  # exclude the baseline period
    tmax = 600
    con, freqs, times, n_epochs, n_tapers = spectral_connectivity(
         aw_S35, method='wpli2_debiased', mode='multitaper', sfreq=sfreq, fmin=fmin, fmax=fmax,
         faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
    
    fname_souce = save_path + cname + sname + '_alpha35-con.csv'
    with open(fname_souce, 'w') as f:
        writer = csv.writer(f, lineterminator='\n') # 改行コード（\n）を指定しておく
        writer.writerows(con[:28,:28,0]) # 2次元配列も書き込める

    tmin = 0  # exclude the baseline period
    tmax = 600
    con, freqs, times, n_epochs, n_tapers = spectral_connectivity(
         aw_S36, method='wpli2_debiased', mode='multitaper', sfreq=sfreq, fmin=fmin, fmax=fmax,
         faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
    
    fname_souce = save_path + cname + sname + '_alpha36-con.csv'
    with open(fname_souce, 'w') as f:
        writer = csv.writer(f, lineterminator='\n') # 改行コード（\n）を指定しておく
        writer.writerows(con[:28,:28,0]) # 2次元配列も書き込める
        
    tmin = 0  # exclude the baseline period
    tmax = 600
    con, freqs, times, n_epochs, n_tapers = spectral_connectivity(
         aw_S37, method='wpli2_debiased', mode='multitaper', sfreq=sfreq, fmin=fmin, fmax=fmax,
         faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
    
    fname_souce = save_path + cname + sname + '_alpha37-con.csv'
    with open(fname_souce, 'w') as f:
        writer = csv.writer(f, lineterminator='\n') # 改行コード（\n）を指定しておく
        writer.writerows(con[:28,:28,0]) # 2次元配列も書き込める
        
    tmin = 0  # exclude the baseline period
    tmax = 600
    con, freqs, times, n_epochs, n_tapers = spectral_connectivity(
         aw_S38, method='wpli2_debiased', mode='multitaper', sfreq=sfreq, fmin=fmin, fmax=fmax,
         faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
    
    fname_souce = save_path + cname + sname + '_alpha38-con.csv'
    with open(fname_souce, 'w') as f:
        writer = csv.writer(f, lineterminator='\n') # 改行コード（\n）を指定しておく
        writer.writerows(con[:28,:28,0]) # 2次元配列も書き込める

    tmin = 0  # exclude the baseline period
    tmax = 600
    con, freqs, times, n_epochs, n_tapers = spectral_connectivity(
         aw_S39, method='wpli2_debiased', mode='multitaper', sfreq=sfreq, fmin=fmin, fmax=fmax,
         faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
    
    fname_souce = save_path + cname + sname + '_alpha39-con.csv'
    with open(fname_souce, 'w') as f:
        writer = csv.writer(f, lineterminator='\n') # 改行コード（\n）を指定しておく
        writer.writerows(con[:28,:28,0]) # 2次元配列も書き込める
        
    tmin = 0  # exclude the baseline period
    tmax = 600
    con, freqs, times, n_epochs, n_tapers = spectral_connectivity(
         aw_S40, method='wpli2_debiased', mode='multitaper', sfreq=sfreq, fmin=fmin, fmax=fmax,
         faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
    
    fname_souce = save_path + cname + sname + '_alpha40-con.csv'
    with open(fname_souce, 'w') as f:
        writer = csv.writer(f, lineterminator='\n') # 改行コード（\n）を指定しておく
        writer.writerows(con[:28,:28,0]) # 2次元配列も書き込める
