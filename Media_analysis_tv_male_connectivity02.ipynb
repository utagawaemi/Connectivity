# %%
# %matplotlib inline

import os.path as op
import numpy as np
import matplotlib.pyplot as plt
from scipy import linalg

import mne
from mne.time_frequency import tfr_morlet, psd_multitaper
from mne.connectivity import spectral_connectivity

import csv

# %%
IDs = ['01', '02', '03', '04', '05', '06', '07', '08', '09', '10', '11', '12']

cname = 'male'
data_path = '/Users/emi/Desktop/media_TBS/media2/adj_tv/'
save_path = '/Users/emi/Desktop/media_TBS/media2/'

# %%
for i in range(len(IDs)):  

    sname = IDs[i]
    fname = data_path + cname + sname + '_tv_adj.set'
    mon = mne.channels.read_montage(kind = 'standard_1020') 
    aw = mne.io.read_epochs_eeglab(fname,montage=mon,
                                  eog=('EOG1', 'EOG2'))

    #for i in range(len(IDs)):  

    #sname = IDs[i]
    #fname = data_path + cname +sname + '_tv_adj.set'
    
    picks = mne.pick_types(aw.info, meg=False, eeg=True, eog=False, stim=False)  #読み込むチャンネルを設定
    
    aw_S1 = aw['TV']
    
    #### theta波 4-7Hz : Baseline
    fmin, fmax = 4., 7.
    sfreq = aw_S1.info['sfreq'] 
    
    tmin = 0.3  # exclude the baseline period
    tmax = 0.5
    con, freqs, times, n_epochs, n_tapers = spectral_connectivity(
         aw_S1, method='wpli2_debiased', mode='multitaper', sfreq=sfreq, fmin=fmin, fmax=fmax,
         faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
    
    fname_souce = save_path + cname + sname + '_tv_adj_Nbas_theta000-con.csv'
    with open(fname_souce, 'w') as f:
        writer = csv.writer(f, lineterminator='\n') # 改行コード（\n）を指定しておく
        writer.writerows(con[:28,:28,0]) # 2次元配列も書き込める


    tmin = 0.5  # exclude the baseline period
    tmax = 0.7
    con, freqs, times, n_epochs, n_tapers = spectral_connectivity(
        aw_S1, method='wpli2_debiased', mode='multitaper', sfreq=sfreq, fmin=fmin, fmax=fmax,
        faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
    
    fname_souce = save_path + cname + sname + '_tv_adj_S1_theta000-con.csv'
    with open(fname_souce, 'w') as f:
        writer = csv.writer(f, lineterminator='\n') # 改行コード（\n）を指定しておく
        writer.writerows(con[:28,:28,0]) # 2次元配列も書き込める

        
    tmin = 0.7  # exclude the baseline period
    tmax = 0.9
    con, freqs, times, n_epochs, n_tapers = spectral_connectivity(
        aw_S1, method='wpli2_debiased', mode='multitaper', sfreq=sfreq, fmin=fmin, fmax=fmax,
        faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
    
    fname_souce = save_path + cname + sname + '_tv_adj_S1_theta200-con.csv'
    with open(fname_souce, 'w') as f:
        writer = csv.writer(f, lineterminator='\n') # 改行コード（\n）を指定しておく
        writer.writerows(con[:28,:28,0]) # 2次元配列も書き込める

        
    tmin = 0.9  # exclude the baseline period
    tmax = 1.1
    con, freqs, times, n_epochs, n_tapers = spectral_connectivity(
        aw_S1, method='wpli2_debiased', mode='multitaper', sfreq=sfreq, fmin=fmin, fmax=fmax,
        faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
    
    fname_souce = save_path + cname + sname + '_tv_adj_S1_theta400-con.csv'
    with open(fname_souce, 'w') as f:
        writer = csv.writer(f, lineterminator='\n') # 改行コード（\n）を指定しておく
        writer.writerows(con[:28,:28,0]) # 2次元配列も書き込める

        
    tmin = 1.1  # exclude the baseline period
    tmax = 1.3
    con, freqs, times, n_epochs, n_tapers = spectral_connectivity(
        aw_S1, method='wpli2_debiased', mode='multitaper', sfreq=sfreq, fmin=fmin, fmax=fmax,
        faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
    
    fname_souce = save_path + cname + sname + '_tv_adj_S1_theta600-con.csv'
    with open(fname_souce, 'w') as f:
        writer = csv.writer(f, lineterminator='\n') # 改行コード（\n）を指定しておく
        writer.writerows(con[:28,:28,0]) # 2次元配列も書き込める

        
    tmin = 1.3  # exclude the baseline period
    tmax = 1.5
    con, freqs, times, n_epochs, n_tapers = spectral_connectivity(
        aw_S1, method='wpli2_debiased', mode='multitaper', sfreq=sfreq, fmin=fmin, fmax=fmax,
        faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
    
    fname_souce = save_path + cname + sname + '_tv_adj_S1_theta800-con.csv'
    with open(fname_souce, 'w') as f:
        writer = csv.writer(f, lineterminator='\n') # 改行コード（\n）を指定しておく
        writer.writerows(con[:28,:28,0]) # 2次元配列も書き込める

        
        
    #### alpha波 4-7Hz : Baseline
    
    fmin, fmax = 8., 13.
    sfreq = aw_S1.info['sfreq'] 
    
    
    tmin = 0.3  # exclude the baseline period
    tmax = 0.5
    con, freqs, times, n_epochs, n_tapers = spectral_connectivity(
        aw_S1, method='wpli2_debiased', mode='multitaper', sfreq=sfreq, fmin=fmin, fmax=fmax,
        faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
    
    fname_souce = save_path + cname + sname + '_tv_adj_Nbas_alpha000-con.csv'
    with open(fname_souce, 'w') as f:
        writer = csv.writer(f, lineterminator='\n') # 改行コード（\n）を指定しておく
        writer.writerows(con[:28,:28,0]) # 2次元配列も書き込める

    tmin = 0.5  # exclude the baseline period
    tmax = 0.7
    con, freqs, times, n_epochs, n_tapers = spectral_connectivity(
        aw_S1, method='wpli2_debiased', mode='multitaper', sfreq=sfreq, fmin=fmin, fmax=fmax,
        faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
    
    fname_souce = save_path + cname + sname + '_tv_adj_S1_alpha000-con.csv'
    with open(fname_souce, 'w') as f:
        writer = csv.writer(f, lineterminator='\n') # 改行コード（\n）を指定しておく
        writer.writerows(con[:28,:28,0]) # 2次元配列も書き込める
        
        
    tmin = 0.7  # exclude the baseline period
    tmax = 0.9
    con, freqs, times, n_aw, n_tapers = spectral_connectivity(
        aw_S1, method='wpli2_debiased', mode='multitaper', sfreq=sfreq, fmin=fmin, fmax=fmax,
        faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)

    fname_souce = save_path + cname + sname + '_tv_adj_S1_alpha200-con.csv'
    with open(fname_souce, 'w') as f:
        writer = csv.writer(f, lineterminator='\n') # 改行コード（\n）を指定しておく
        writer.writerows(con[:28,:28,0]) # 2次元配列も書き込める        
        
        
    tmin = 0.9  # exclude the baseline period
    tmax = 1.1
    con, freqs, times, n_epochs, n_tapers = spectral_connectivity(
        aw_S1, method='wpli2_debiased', mode='multitaper', sfreq=sfreq, fmin=fmin, fmax=fmax,
        faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
    
    fname_souce = save_path + cname + sname + '_tv_adj_S1_alpha400-con.csv'
    with open(fname_souce, 'w') as f:
        writer = csv.writer(f, lineterminator='\n') # 改行コード（\n）を指定しておく
        writer.writerows(con[:28,:28,0]) # 2次元配列も書き込める
        
    tmin = 1.1  # exclude the baseline period
    tmax = 1.3
    con, freqs, times, n_epochs, n_tapers = spectral_connectivity(
        aw_S1, method='wpli2_debiased', mode='multitaper', sfreq=sfreq, fmin=fmin, fmax=fmax,
        faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
    
    fname_souce = save_path + cname + sname + '_tv_adj_S1_alpha600-con.csv'
    with open(fname_souce, 'w') as f:
        writer = csv.writer(f, lineterminator='\n') # 改行コード（\n）を指定しておく
        writer.writerows(con[:28,:28,0]) # 2次元配列も書き込める
        
    tmin = 1.3  # exclude the baseline period
    tmax = 1.5
    con, freqs, times, n_epochs, n_tapers = spectral_connectivity(
        aw_S1, method='wpli2_debiased', mode='multitaper', sfreq=sfreq, fmin=fmin, fmax=fmax,
        faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
    
    fname_souce = save_path + cname + sname + '_tv_adj_S1_alpha800-con.csv'
    with open(fname_souce, 'w') as f:
        writer = csv.writer(f, lineterminator='\n') # 改行コード（\n）を指定しておく
        writer.writerows(con[:28,:28,0]) # 2次元配列も書き込める
        
        
          # ### beta波 4-7Hz : Baseline
    
    fmin, fmax = 14., 30.
    sfreq = aw_S1.info['sfreq'] 
    
    tmin = 0.3  # exclude the baseline period
    tmax = 0.5
    con, freqs, times, n_epochs, n_tapers = spectral_connectivity(
        aw_S1, method='wpli2_debiased', mode='multitaper', sfreq=sfreq, fmin=fmin, fmax=fmax,
        faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
    
    fname_souce = save_path + cname + sname + '_tv_adj_Nbas_beta000-con.csv'
    with open(fname_souce, 'w') as f:
        writer = csv.writer(f, lineterminator='\n') # 改行コード（\n）を指定しておく
        writer.writerows(con[:28,:28,0]) # 2次元配列も書き込める
        
    tmin = 0.5  # exclude the baseline period
    tmax = 0.7
    con, freqs, times, n_epochs, n_tapers = spectral_connectivity(
        aw_S1, method='wpli2_debiased', mode='multitaper', sfreq=sfreq, fmin=fmin, fmax=fmax,
        faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
    
    fname_souce = save_path + cname + sname + '_tv_adj_S1_beta000-con.csv'
    with open(fname_souce, 'w') as f:
        writer = csv.writer(f, lineterminator='\n') # 改行コード（\n）を指定しておく
        writer.writerows(con[:28,:28,0]) # 2次元配列も書き込める

    tmin = 0.7  # exclude the baseline period
    tmax = 0.9
    con, freqs, times, n_epochs, n_tapers = spectral_connectivity(
        aw_S1, method='wpli2_debiased', mode='multitaper', sfreq=sfreq, fmin=fmin, fmax=fmax,
        faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)

    fname_souce = save_path + sname + cname + '_tv_adj_S1_beta200-con.csv'
    with open(fname_souce, 'w') as f:
        writer = csv.writer(f, lineterminator='\n') # 改行コード（\n）を指定しておく
        writer.writerows(con[:28,:28,0]) # 2次元配列も書き込める
        
    tmin = 0.9  # exclude the baseline period
    tmax = 1.1
    con, freqs, times, n_epochs, n_tapers = spectral_connectivity(
        aw_S1, method='wpli2_debiased', mode='multitaper', sfreq=sfreq, fmin=fmin, fmax=fmax,
        faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)

    fname_souce = save_path + sname + cname + '_tv_adj_S1_beta400-con.csv'
    with open(fname_souce, 'w') as f:
        writer = csv.writer(f, lineterminator='\n') # 改行コード（\n）を指定しておく
        writer.writerows(con[:28,:28,0]) # 2次元配列も書き込める
        
    tmin = 1.1  # exclude the baseline period
    tmax = 1.3
    con, freqs, times, n_epochs, n_tapers = spectral_connectivity(
        aw_S1, method='wpli2_debiased', mode='multitaper', sfreq=sfreq, fmin=fmin, fmax=fmax,
        faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)

    fname_souce = save_path + sname + cname + '_tv_adj_S1_beta600-con.csv'
    with open(fname_souce, 'w') as f:
        writer = csv.writer(f, lineterminator='\n') # 改行コード（\n）を指定しておく
        writer.writerows(con[:28,:28,0]) # 2次元配列も書き込める

    tmin = 1.3  # exclude the baseline period
    tmax = 1.5
    con, freqs, times, n_epochs, n_tapers = spectral_connectivity(
        aw_S1, method='wpli2_debiased', mode='multitaper', sfreq=sfreq, fmin=fmin, fmax=fmax,
        faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)

    fname_souce = save_path + sname + cname + '_tv_adj_S1_beta800-con.csv'
    with open(fname_souce, 'w') as f:
        writer = csv.writer(f, lineterminator='\n') # 改行コード（\n）を指定しておく
        writer.writerows(con[:28,:28,0]) # 2次元配列も書き込める
# Out:
# Extracting parameters from /Users/emi/Desktop/media_TBS/media2/adj_tv/male01_tv_adj.set...
# <ipython-input-5-c085383cba6a>:7: RuntimeWarning: At least one epoch has multiple events. Only the latency of the first event will be retained.
#   eog=('EOG1', 'EOG2'))
# <ipython-input-5-c085383cba6a>:7: RuntimeWarning: The following EEG sensors did not have a position specified in the selected montage: [u'EOG1', u'EOG2']. Their position has been left untouched.
#   eog=('EOG1', 'EOG2'))
# 25 matching events found
# No baseline correction applied
# Not setting metadata
# 0 projection items activated
# Ready.
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 435 connections
#     using t=0.300s..0.500s for estimation (201 points)
#     frequencies: 5.0Hz..5.0Hz (1 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing connectivity for epoch 1
#     computing connectivity for epoch 2
#     computing connectivity for epoch 3
#     computing connectivity for epoch 4
#     computing connectivity for epoch 5
#     computing connectivity for epoch 6
#     computing connectivity for epoch 7
#     computing connectivity for epoch 8
#     computing connectivity for epoch 9
#     computing connectivity for epoch 10
#     computing connectivity for epoch 11
#     computing connectivity for epoch 12
#     computing connectivity for epoch 13
#     computing connectivity for epoch 14
#     computing connectivity for epoch 15
#     computing connectivity for epoch 16
#     computing connectivity for epoch 17
#     computing connectivity for epoch 18
#     computing connectivity for epoch 19
#     computing connectivity for epoch 20
#     computing connectivity for epoch 21
#     computing connectivity for epoch 22
#     computing connectivity for epoch 23
#     computing connectivity for epoch 24
#     computing connectivity for epoch 25
#     assembling connectivity matrix (filling the upper triangular region of the matrix)
# [Connectivity computation done]
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 435 connections
#     using t=0.500s..0.700s for estimation (201 points)
#     frequencies: 5.0Hz..5.0Hz (1 points)
#     connectivity scores will be averaged for each band
# <ipython-input-5-c085383cba6a>:26: RuntimeWarning: fmin=4.000 Hz corresponds to 0.804 < 5 cycles based on the epoch length 0.201 sec, need at least 1.250 sec epochs or fmin=24.876. Spectrum estimate will be unreliable.
#   faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
# <ipython-input-5-c085383cba6a>:38: RuntimeWarning: fmin=4.000 Hz corresponds to 0.804 < 5 cycles based on the epoch length 0.201 sec, need at least 1.250 sec epochs or fmin=24.876. Spectrum estimate will be unreliable.
#   faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing connectivity for epoch 1
#     computing connectivity for epoch 2
#     computing connectivity for epoch 3
#     computing connectivity for epoch 4
#     computing connectivity for epoch 5
#     computing connectivity for epoch 6
#     computing connectivity for epoch 7
#     computing connectivity for epoch 8
#     computing connectivity for epoch 9
#     computing connectivity for epoch 10
#     computing connectivity for epoch 11
#     computing connectivity for epoch 12
#     computing connectivity for epoch 13
#     computing connectivity for epoch 14
#     computing connectivity for epoch 15
#     computing connectivity for epoch 16
#     computing connectivity for epoch 17
#     computing connectivity for epoch 18
#     computing connectivity for epoch 19
#     computing connectivity for epoch 20
#     computing connectivity for epoch 21
#     computing connectivity for epoch 22
#     computing connectivity for epoch 23
#     computing connectivity for epoch 24
#     computing connectivity for epoch 25
#     assembling connectivity matrix (filling the upper triangular region of the matrix)
# [Connectivity computation done]
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 435 connections
#     using t=0.700s..0.900s for estimation (201 points)
#     frequencies: 5.0Hz..5.0Hz (1 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing connectivity for epoch 1
#     computing connectivity for epoch 2
#     computing connectivity for epoch 3
#     computing connectivity for epoch 4
#     computing connectivity for epoch 5
#     computing connectivity for epoch 6
#     computing connectivity for epoch 7
#     computing connectivity for epoch 8
#     computing connectivity for epoch 9
#     computing connectivity for epoch 10
#     computing connectivity for epoch 11
#     computing connectivity for epoch 12
#     computing connectivity for epoch 13
#     computing connectivity for epoch 14
#     computing connectivity for epoch 15
#     computing connectivity for epoch 16
#     computing connectivity for epoch 17
#     computing connectivity for epoch 18
#     computing connectivity for epoch 19
#     computing connectivity for epoch 20
#     computing connectivity for epoch 21
#     computing connectivity for epoch 22
#     computing connectivity for epoch 23
# <ipython-input-5-c085383cba6a>:50: RuntimeWarning: fmin=4.000 Hz corresponds to 0.804 < 5 cycles based on the epoch length 0.201 sec, need at least 1.250 sec epochs or fmin=24.876. Spectrum estimate will be unreliable.
#   faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
#     computing connectivity for epoch 24
#     computing connectivity for epoch 25
#     assembling connectivity matrix (filling the upper triangular region of the matrix)
# [Connectivity computation done]
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 435 connections
#     using t=0.900s..1.100s for estimation (201 points)
#     frequencies: 5.0Hz..5.0Hz (1 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing connectivity for epoch 1
#     computing connectivity for epoch 2
#     computing connectivity for epoch 3
#     computing connectivity for epoch 4
#     computing connectivity for epoch 5
#     computing connectivity for epoch 6
#     computing connectivity for epoch 7
#     computing connectivity for epoch 8
#     computing connectivity for epoch 9
#     computing connectivity for epoch 10
#     computing connectivity for epoch 11
#     computing connectivity for epoch 12
#     computing connectivity for epoch 13
#     computing connectivity for epoch 14
#     computing connectivity for epoch 15
#     computing connectivity for epoch 16
#     computing connectivity for epoch 17
#     computing connectivity for epoch 18
#     computing connectivity for epoch 19
#     computing connectivity for epoch 20
#     computing connectivity for epoch 21
#     computing connectivity for epoch 22
#     computing connectivity for epoch 23
#     computing connectivity for epoch 24
#     computing connectivity for epoch 25
#     assembling connectivity matrix (filling the upper triangular region of the matrix)
# [Connectivity computation done]
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 435 connections
#     using t=1.100s..1.300s for estimation (201 points)
#     frequencies: 5.0Hz..5.0Hz (1 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing connectivity for epoch 1
#     computing connectivity for epoch 2
#     computing connectivity for epoch 3
#     computing connectivity for epoch 4
#     computing connectivity for epoch 5
#     computing connectivity for epoch 6
#     computing connectivity for epoch 7
# <ipython-input-5-c085383cba6a>:62: RuntimeWarning: fmin=4.000 Hz corresponds to 0.804 < 5 cycles based on the epoch length 0.201 sec, need at least 1.250 sec epochs or fmin=24.876. Spectrum estimate will be unreliable.
#   faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
# <ipython-input-5-c085383cba6a>:74: RuntimeWarning: fmin=4.000 Hz corresponds to 0.804 < 5 cycles based on the epoch length 0.201 sec, need at least 1.250 sec epochs or fmin=24.876. Spectrum estimate will be unreliable.
#   faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
#     computing connectivity for epoch 8
#     computing connectivity for epoch 9
#     computing connectivity for epoch 10
#     computing connectivity for epoch 11
#     computing connectivity for epoch 12
#     computing connectivity for epoch 13
#     computing connectivity for epoch 14
#     computing connectivity for epoch 15
#     computing connectivity for epoch 16
#     computing connectivity for epoch 17
#     computing connectivity for epoch 18
#     computing connectivity for epoch 19
#     computing connectivity for epoch 20
#     computing connectivity for epoch 21
#     computing connectivity for epoch 22
#     computing connectivity for epoch 23
#     computing connectivity for epoch 24
#     computing connectivity for epoch 25
#     assembling connectivity matrix (filling the upper triangular region of the matrix)
# [Connectivity computation done]
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 435 connections
#     using t=1.300s..1.500s for estimation (201 points)
#     frequencies: 5.0Hz..5.0Hz (1 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing connectivity for epoch 1
#     computing connectivity for epoch 2
#     computing connectivity for epoch 3
#     computing connectivity for epoch 4
#     computing connectivity for epoch 5
#     computing connectivity for epoch 6
#     computing connectivity for epoch 7
#     computing connectivity for epoch 8
#     computing connectivity for epoch 9
#     computing connectivity for epoch 10
#     computing connectivity for epoch 11
#     computing connectivity for epoch 12
#     computing connectivity for epoch 13
#     computing connectivity for epoch 14
#     computing connectivity for epoch 15
#     computing connectivity for epoch 16
#     computing connectivity for epoch 17
#     computing connectivity for epoch 18
#     computing connectivity for epoch 19
#     computing connectivity for epoch 20
#     computing connectivity for epoch 21
#     computing connectivity for epoch 22
#     computing connectivity for epoch 23
#     computing connectivity for epoch 24
#     computing connectivity for epoch 25
#     assembling connectivity matrix (filling the upper triangular region of the matrix)
# [Connectivity computation done]
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 435 connections
#     using t=0.300s..0.500s for estimation (201 points)
#     frequencies: 10.0Hz..10.0Hz (1 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing connectivity for epoch 1
#     computing connectivity for epoch 2
#     computing connectivity for epoch 3
#     computing connectivity for epoch 4
# <ipython-input-5-c085383cba6a>:86: RuntimeWarning: fmin=4.000 Hz corresponds to 0.804 < 5 cycles based on the epoch length 0.201 sec, need at least 1.250 sec epochs or fmin=24.876. Spectrum estimate will be unreliable.
#   faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
# <ipython-input-5-c085383cba6a>:105: RuntimeWarning: fmin=8.000 Hz corresponds to 1.608 < 5 cycles based on the epoch length 0.201 sec, need at least 0.625 sec epochs or fmin=24.876. Spectrum estimate will be unreliable.
#   faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
#     computing connectivity for epoch 5
#     computing connectivity for epoch 6
#     computing connectivity for epoch 7
#     computing connectivity for epoch 8
#     computing connectivity for epoch 9
#     computing connectivity for epoch 10
#     computing connectivity for epoch 11
#     computing connectivity for epoch 12
#     computing connectivity for epoch 13
#     computing connectivity for epoch 14
#     computing connectivity for epoch 15
#     computing connectivity for epoch 16
#     computing connectivity for epoch 17
#     computing connectivity for epoch 18
#     computing connectivity for epoch 19
#     computing connectivity for epoch 20
#     computing connectivity for epoch 21
#     computing connectivity for epoch 22
#     computing connectivity for epoch 23
#     computing connectivity for epoch 24
#     computing connectivity for epoch 25
#     assembling connectivity matrix (filling the upper triangular region of the matrix)
# [Connectivity computation done]
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 435 connections
#     using t=0.500s..0.700s for estimation (201 points)
#     frequencies: 10.0Hz..10.0Hz (1 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing connectivity for epoch 1
#     computing connectivity for epoch 2
#     computing connectivity for epoch 3
#     computing connectivity for epoch 4
#     computing connectivity for epoch 5
#     computing connectivity for epoch 6
#     computing connectivity for epoch 7
#     computing connectivity for epoch 8
#     computing connectivity for epoch 9
#     computing connectivity for epoch 10
#     computing connectivity for epoch 11
#     computing connectivity for epoch 12
#     computing connectivity for epoch 13
#     computing connectivity for epoch 14
#     computing connectivity for epoch 15
#     computing connectivity for epoch 16
#     computing connectivity for epoch 17
#     computing connectivity for epoch 18
#     computing connectivity for epoch 19
#     computing connectivity for epoch 20
#     computing connectivity for epoch 21
#     computing connectivity for epoch 22
#     computing connectivity for epoch 23
#     computing connectivity for epoch 24
#     computing connectivity for epoch 25
#     assembling connectivity matrix (filling the upper triangular region of the matrix)
# [Connectivity computation done]
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 435 connections
#     using t=0.700s..0.900s for estimation (201 points)
#     frequencies: 10.0Hz..10.0Hz (1 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing connectivity for epoch 1
#     computing connectivity for epoch 2
#     computing connectivity for epoch 3
#     computing connectivity for epoch 4
#     computing connectivity for epoch 5
#     computing connectivity for epoch 6
#     computing connectivity for epoch 7
#     computing connectivity for epoch 8
#     computing connectivity for epoch 9
#     computing connectivity for epoch 10
#     computing connectivity for epoch 11
#     computing connectivity for epoch 12
#     computing connectivity for epoch 13
#     computing connectivity for epoch 14
#     computing connectivity for epoch 15
#     computing connectivity for epoch 16
#     computing connectivity for epoch 17
# <ipython-input-5-c085383cba6a>:116: RuntimeWarning: fmin=8.000 Hz corresponds to 1.608 < 5 cycles based on the epoch length 0.201 sec, need at least 0.625 sec epochs or fmin=24.876. Spectrum estimate will be unreliable.
#   faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
# <ipython-input-5-c085383cba6a>:128: RuntimeWarning: fmin=8.000 Hz corresponds to 1.608 < 5 cycles based on the epoch length 0.201 sec, need at least 0.625 sec epochs or fmin=24.876. Spectrum estimate will be unreliable.
#   faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
#     computing connectivity for epoch 18
#     computing connectivity for epoch 19
#     computing connectivity for epoch 20
#     computing connectivity for epoch 21
#     computing connectivity for epoch 22
#     computing connectivity for epoch 23
#     computing connectivity for epoch 24
#     computing connectivity for epoch 25
#     assembling connectivity matrix (filling the upper triangular region of the matrix)
# [Connectivity computation done]
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 435 connections
#     using t=0.900s..1.100s for estimation (201 points)
#     frequencies: 10.0Hz..10.0Hz (1 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing connectivity for epoch 1
#     computing connectivity for epoch 2
#     computing connectivity for epoch 3
#     computing connectivity for epoch 4
#     computing connectivity for epoch 5
#     computing connectivity for epoch 6
#     computing connectivity for epoch 7
#     computing connectivity for epoch 8
#     computing connectivity for epoch 9
#     computing connectivity for epoch 10
#     computing connectivity for epoch 11
#     computing connectivity for epoch 12
#     computing connectivity for epoch 13
#     computing connectivity for epoch 14
#     computing connectivity for epoch 15
#     computing connectivity for epoch 16
#     computing connectivity for epoch 17
#     computing connectivity for epoch 18
#     computing connectivity for epoch 19
#     computing connectivity for epoch 20
#     computing connectivity for epoch 21
#     computing connectivity for epoch 22
#     computing connectivity for epoch 23
#     computing connectivity for epoch 24
#     computing connectivity for epoch 25
#     assembling connectivity matrix (filling the upper triangular region of the matrix)
# [Connectivity computation done]
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 435 connections
#     using t=1.100s..1.300s for estimation (201 points)
#     frequencies: 10.0Hz..10.0Hz (1 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing connectivity for epoch 1
#     computing connectivity for epoch 2
#     computing connectivity for epoch 3
#     computing connectivity for epoch 4
#     computing connectivity for epoch 5
#     computing connectivity for epoch 6
#     computing connectivity for epoch 7
#     computing connectivity for epoch 8
#     computing connectivity for epoch 9
#     computing connectivity for epoch 10
#     computing connectivity for epoch 11
#     computing connectivity for epoch 12
#     computing connectivity for epoch 13
#     computing connectivity for epoch 14
#     computing connectivity for epoch 15
#     computing connectivity for epoch 16
#     computing connectivity for epoch 17
#     computing connectivity for epoch 18
# <ipython-input-5-c085383cba6a>:140: RuntimeWarning: fmin=8.000 Hz corresponds to 1.608 < 5 cycles based on the epoch length 0.201 sec, need at least 0.625 sec epochs or fmin=24.876. Spectrum estimate will be unreliable.
#   faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
# <ipython-input-5-c085383cba6a>:151: RuntimeWarning: fmin=8.000 Hz corresponds to 1.608 < 5 cycles based on the epoch length 0.201 sec, need at least 0.625 sec epochs or fmin=24.876. Spectrum estimate will be unreliable.
#   faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
#     computing connectivity for epoch 19
#     computing connectivity for epoch 20
#     computing connectivity for epoch 21
#     computing connectivity for epoch 22
#     computing connectivity for epoch 23
#     computing connectivity for epoch 24
#     computing connectivity for epoch 25
#     assembling connectivity matrix (filling the upper triangular region of the matrix)
# [Connectivity computation done]
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 435 connections
#     using t=1.300s..1.500s for estimation (201 points)
#     frequencies: 10.0Hz..10.0Hz (1 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing connectivity for epoch 1
#     computing connectivity for epoch 2
#     computing connectivity for epoch 3
#     computing connectivity for epoch 4
#     computing connectivity for epoch 5
#     computing connectivity for epoch 6
#     computing connectivity for epoch 7
#     computing connectivity for epoch 8
#     computing connectivity for epoch 9
#     computing connectivity for epoch 10
#     computing connectivity for epoch 11
#     computing connectivity for epoch 12
#     computing connectivity for epoch 13
#     computing connectivity for epoch 14
#     computing connectivity for epoch 15
#     computing connectivity for epoch 16
#     computing connectivity for epoch 17
#     computing connectivity for epoch 18
#     computing connectivity for epoch 19
#     computing connectivity for epoch 20
#     computing connectivity for epoch 21
#     computing connectivity for epoch 22
#     computing connectivity for epoch 23
#     computing connectivity for epoch 24
#     computing connectivity for epoch 25
#     assembling connectivity matrix (filling the upper triangular region of the matrix)
# [Connectivity computation done]
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 435 connections
#     using t=0.300s..0.500s for estimation (201 points)
#     frequencies: 14.9Hz..29.9Hz (4 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing connectivity for epoch 1
#     computing connectivity for epoch 2
#     computing connectivity for epoch 3
#     computing connectivity for epoch 4
#     computing connectivity for epoch 5
#     computing connectivity for epoch 6
#     computing connectivity for epoch 7
#     computing connectivity for epoch 8
#     computing connectivity for epoch 9
#     computing connectivity for epoch 10
#     computing connectivity for epoch 11
#     computing connectivity for epoch 12
#     computing connectivity for epoch 13
#     computing connectivity for epoch 14
# <ipython-input-5-c085383cba6a>:162: RuntimeWarning: fmin=8.000 Hz corresponds to 1.608 < 5 cycles based on the epoch length 0.201 sec, need at least 0.625 sec epochs or fmin=24.876. Spectrum estimate will be unreliable.
#   faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
# <ipython-input-5-c085383cba6a>:179: RuntimeWarning: fmin=14.000 Hz corresponds to 2.814 < 5 cycles based on the epoch length 0.201 sec, need at least 0.357 sec epochs or fmin=24.876. Spectrum estimate will be unreliable.
#   faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
#     computing connectivity for epoch 15
#     computing connectivity for epoch 16
#     computing connectivity for epoch 17
#     computing connectivity for epoch 18
#     computing connectivity for epoch 19
#     computing connectivity for epoch 20
#     computing connectivity for epoch 21
#     computing connectivity for epoch 22
#     computing connectivity for epoch 23
#     computing connectivity for epoch 24
#     computing connectivity for epoch 25
#     assembling connectivity matrix (filling the upper triangular region of the matrix)
# [Connectivity computation done]
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 435 connections
#     using t=0.500s..0.700s for estimation (201 points)
#     frequencies: 14.9Hz..29.9Hz (4 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing connectivity for epoch 1
#     computing connectivity for epoch 2
#     computing connectivity for epoch 3
#     computing connectivity for epoch 4
#     computing connectivity for epoch 5
#     computing connectivity for epoch 6
#     computing connectivity for epoch 7
#     computing connectivity for epoch 8
#     computing connectivity for epoch 9
#     computing connectivity for epoch 10
#     computing connectivity for epoch 11
#     computing connectivity for epoch 12
#     computing connectivity for epoch 13
#     computing connectivity for epoch 14
#     computing connectivity for epoch 15
#     computing connectivity for epoch 16
#     computing connectivity for epoch 17
#     computing connectivity for epoch 18
#     computing connectivity for epoch 19
#     computing connectivity for epoch 20
#     computing connectivity for epoch 21
#     computing connectivity for epoch 22
#     computing connectivity for epoch 23
#     computing connectivity for epoch 24
#     computing connectivity for epoch 25
#     assembling connectivity matrix (filling the upper triangular region of the matrix)
# [Connectivity computation done]
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 435 connections
#     using t=0.700s..0.900s for estimation (201 points)
#     frequencies: 14.9Hz..29.9Hz (4 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing connectivity for epoch 1
#     computing connectivity for epoch 2
#     computing connectivity for epoch 3
#     computing connectivity for epoch 4
#     computing connectivity for epoch 5
#     computing connectivity for epoch 6
#     computing connectivity for epoch 7
#     computing connectivity for epoch 8
#     computing connectivity for epoch 9
#     computing connectivity for epoch 10
#     computing connectivity for epoch 11
#     computing connectivity for epoch 12
# <ipython-input-5-c085383cba6a>:190: RuntimeWarning: fmin=14.000 Hz corresponds to 2.814 < 5 cycles based on the epoch length 0.201 sec, need at least 0.357 sec epochs or fmin=24.876. Spectrum estimate will be unreliable.
#   faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
# <ipython-input-5-c085383cba6a>:201: RuntimeWarning: fmin=14.000 Hz corresponds to 2.814 < 5 cycles based on the epoch length 0.201 sec, need at least 0.357 sec epochs or fmin=24.876. Spectrum estimate will be unreliable.
#   faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
#     computing connectivity for epoch 13
#     computing connectivity for epoch 14
#     computing connectivity for epoch 15
#     computing connectivity for epoch 16
#     computing connectivity for epoch 17
#     computing connectivity for epoch 18
#     computing connectivity for epoch 19
#     computing connectivity for epoch 20
#     computing connectivity for epoch 21
#     computing connectivity for epoch 22
#     computing connectivity for epoch 23
#     computing connectivity for epoch 24
#     computing connectivity for epoch 25
#     assembling connectivity matrix (filling the upper triangular region of the matrix)
# [Connectivity computation done]
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 435 connections
#     using t=0.900s..1.100s for estimation (201 points)
#     frequencies: 14.9Hz..29.9Hz (4 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing connectivity for epoch 1
#     computing connectivity for epoch 2
#     computing connectivity for epoch 3
#     computing connectivity for epoch 4
#     computing connectivity for epoch 5
#     computing connectivity for epoch 6
#     computing connectivity for epoch 7
#     computing connectivity for epoch 8
#     computing connectivity for epoch 9
#     computing connectivity for epoch 10
#     computing connectivity for epoch 11
#     computing connectivity for epoch 12
#     computing connectivity for epoch 13
#     computing connectivity for epoch 14
#     computing connectivity for epoch 15
#     computing connectivity for epoch 16
#     computing connectivity for epoch 17
#     computing connectivity for epoch 18
#     computing connectivity for epoch 19
#     computing connectivity for epoch 20
#     computing connectivity for epoch 21
#     computing connectivity for epoch 22
#     computing connectivity for epoch 23
#     computing connectivity for epoch 24
#     computing connectivity for epoch 25
#     assembling connectivity matrix (filling the upper triangular region of the matrix)
# [Connectivity computation done]
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 435 connections
#     using t=1.100s..1.300s for estimation (201 points)
#     frequencies: 14.9Hz..29.9Hz (4 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing connectivity for epoch 1
#     computing connectivity for epoch 2
#     computing connectivity for epoch 3
#     computing connectivity for epoch 4
#     computing connectivity for epoch 5
#     computing connectivity for epoch 6
#     computing connectivity for epoch 7
#     computing connectivity for epoch 8
# <ipython-input-5-c085383cba6a>:212: RuntimeWarning: fmin=14.000 Hz corresponds to 2.814 < 5 cycles based on the epoch length 0.201 sec, need at least 0.357 sec epochs or fmin=24.876. Spectrum estimate will be unreliable.
#   faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
# <ipython-input-5-c085383cba6a>:223: RuntimeWarning: fmin=14.000 Hz corresponds to 2.814 < 5 cycles based on the epoch length 0.201 sec, need at least 0.357 sec epochs or fmin=24.876. Spectrum estimate will be unreliable.
#   faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
#     computing connectivity for epoch 9
#     computing connectivity for epoch 10
#     computing connectivity for epoch 11
#     computing connectivity for epoch 12
#     computing connectivity for epoch 13
#     computing connectivity for epoch 14
#     computing connectivity for epoch 15
#     computing connectivity for epoch 16
#     computing connectivity for epoch 17
#     computing connectivity for epoch 18
#     computing connectivity for epoch 19
#     computing connectivity for epoch 20
#     computing connectivity for epoch 21
#     computing connectivity for epoch 22
#     computing connectivity for epoch 23
#     computing connectivity for epoch 24
#     computing connectivity for epoch 25
#     assembling connectivity matrix (filling the upper triangular region of the matrix)
# [Connectivity computation done]
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 435 connections
#     using t=1.300s..1.500s for estimation (201 points)
#     frequencies: 14.9Hz..29.9Hz (4 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing connectivity for epoch 1
#     computing connectivity for epoch 2
#     computing connectivity for epoch 3
#     computing connectivity for epoch 4
#     computing connectivity for epoch 5
#     computing connectivity for epoch 6
#     computing connectivity for epoch 7
#     computing connectivity for epoch 8
#     computing connectivity for epoch 9
#     computing connectivity for epoch 10
#     computing connectivity for epoch 11
#     computing connectivity for epoch 12
#     computing connectivity for epoch 13
#     computing connectivity for epoch 14
#     computing connectivity for epoch 15
#     computing connectivity for epoch 16
#     computing connectivity for epoch 17
#     computing connectivity for epoch 18
#     computing connectivity for epoch 19
#     computing connectivity for epoch 20
#     computing connectivity for epoch 21
#     computing connectivity for epoch 22
#     computing connectivity for epoch 23
#     computing connectivity for epoch 24
#     computing connectivity for epoch 25
#     assembling connectivity matrix (filling the upper triangular region of the matrix)
# [Connectivity computation done]
# Extracting parameters from /Users/emi/Desktop/media_TBS/media2/adj_tv/male02_tv_adj.set...
# <ipython-input-5-c085383cba6a>:234: RuntimeWarning: fmin=14.000 Hz corresponds to 2.814 < 5 cycles based on the epoch length 0.201 sec, need at least 0.357 sec epochs or fmin=24.876. Spectrum estimate will be unreliable.
#   faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
# <ipython-input-5-c085383cba6a>:7: RuntimeWarning: At least one epoch has multiple events. Only the latency of the first event will be retained.
#   eog=('EOG1', 'EOG2'))
# <ipython-input-5-c085383cba6a>:7: RuntimeWarning: The following EEG sensors did not have a position specified in the selected montage: [u'EOG1', u'EOG2']. Their position has been left untouched.
#   eog=('EOG1', 'EOG2'))
# 25 matching events found
# No baseline correction applied
# Not setting metadata
# 0 projection items activated
# Ready.
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 435 connections
#     using t=0.300s..0.500s for estimation (201 points)
#     frequencies: 5.0Hz..5.0Hz (1 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing connectivity for epoch 1
#     computing connectivity for epoch 2
#     computing connectivity for epoch 3
#     computing connectivity for epoch 4
#     computing connectivity for epoch 5
#     computing connectivity for epoch 6
#     computing connectivity for epoch 7
#     computing connectivity for epoch 8
#     computing connectivity for epoch 9
#     computing connectivity for epoch 10
#     computing connectivity for epoch 11
#     computing connectivity for epoch 12
#     computing connectivity for epoch 13
#     computing connectivity for epoch 14
#     computing connectivity for epoch 15
#     computing connectivity for epoch 16
#     computing connectivity for epoch 17
#     computing connectivity for epoch 18
#     computing connectivity for epoch 19
#     computing connectivity for epoch 20
#     computing connectivity for epoch 21
#     computing connectivity for epoch 22
#     computing connectivity for epoch 23
#     computing connectivity for epoch 24
#     computing connectivity for epoch 25
#     assembling connectivity matrix (filling the upper triangular region of the matrix)
# [Connectivity computation done]
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 435 connections
#     using t=0.500s..0.700s for estimation (201 points)
#     frequencies: 5.0Hz..5.0Hz (1 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing connectivity for epoch 1
# <ipython-input-5-c085383cba6a>:26: RuntimeWarning: fmin=4.000 Hz corresponds to 0.804 < 5 cycles based on the epoch length 0.201 sec, need at least 1.250 sec epochs or fmin=24.876. Spectrum estimate will be unreliable.
#   faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
# <ipython-input-5-c085383cba6a>:38: RuntimeWarning: fmin=4.000 Hz corresponds to 0.804 < 5 cycles based on the epoch length 0.201 sec, need at least 1.250 sec epochs or fmin=24.876. Spectrum estimate will be unreliable.
#   faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
#     computing connectivity for epoch 2
#     computing connectivity for epoch 3
#     computing connectivity for epoch 4
#     computing connectivity for epoch 5
#     computing connectivity for epoch 6
#     computing connectivity for epoch 7
#     computing connectivity for epoch 8
#     computing connectivity for epoch 9
#     computing connectivity for epoch 10
#     computing connectivity for epoch 11
#     computing connectivity for epoch 12
#     computing connectivity for epoch 13
#     computing connectivity for epoch 14
#     computing connectivity for epoch 15
#     computing connectivity for epoch 16
#     computing connectivity for epoch 17
#     computing connectivity for epoch 18
#     computing connectivity for epoch 19
#     computing connectivity for epoch 20
#     computing connectivity for epoch 21
#     computing connectivity for epoch 22
#     computing connectivity for epoch 23
#     computing connectivity for epoch 24
#     computing connectivity for epoch 25
#     assembling connectivity matrix (filling the upper triangular region of the matrix)
# [Connectivity computation done]
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 435 connections
#     using t=0.700s..0.900s for estimation (201 points)
#     frequencies: 5.0Hz..5.0Hz (1 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing connectivity for epoch 1
#     computing connectivity for epoch 2
#     computing connectivity for epoch 3
#     computing connectivity for epoch 4
#     computing connectivity for epoch 5
#     computing connectivity for epoch 6
#     computing connectivity for epoch 7
#     computing connectivity for epoch 8
#     computing connectivity for epoch 9
#     computing connectivity for epoch 10
#     computing connectivity for epoch 11
#     computing connectivity for epoch 12
#     computing connectivity for epoch 13
#     computing connectivity for epoch 14
#     computing connectivity for epoch 15
#     computing connectivity for epoch 16
#     computing connectivity for epoch 17
#     computing connectivity for epoch 18
#     computing connectivity for epoch 19
#     computing connectivity for epoch 20
#     computing connectivity for epoch 21
#     computing connectivity for epoch 22
#     computing connectivity for epoch 23
#     computing connectivity for epoch 24
#     computing connectivity for epoch 25
#     assembling connectivity matrix (filling the upper triangular region of the matrix)
# [Connectivity computation done]
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 435 connections
#     using t=0.900s..1.100s for estimation (201 points)
#     frequencies: 5.0Hz..5.0Hz (1 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing connectivity for epoch 1
#     computing connectivity for epoch 2
#     computing connectivity for epoch 3
#     computing connectivity for epoch 4
#     computing connectivity for epoch 5
# <ipython-input-5-c085383cba6a>:50: RuntimeWarning: fmin=4.000 Hz corresponds to 0.804 < 5 cycles based on the epoch length 0.201 sec, need at least 1.250 sec epochs or fmin=24.876. Spectrum estimate will be unreliable.
#   faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
# <ipython-input-5-c085383cba6a>:62: RuntimeWarning: fmin=4.000 Hz corresponds to 0.804 < 5 cycles based on the epoch length 0.201 sec, need at least 1.250 sec epochs or fmin=24.876. Spectrum estimate will be unreliable.
#   faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
#     computing connectivity for epoch 6
#     computing connectivity for epoch 7
#     computing connectivity for epoch 8
#     computing connectivity for epoch 9
#     computing connectivity for epoch 10
#     computing connectivity for epoch 11
#     computing connectivity for epoch 12
#     computing connectivity for epoch 13
#     computing connectivity for epoch 14
#     computing connectivity for epoch 15
#     computing connectivity for epoch 16
#     computing connectivity for epoch 17
#     computing connectivity for epoch 18
#     computing connectivity for epoch 19
#     computing connectivity for epoch 20
#     computing connectivity for epoch 21
#     computing connectivity for epoch 22
#     computing connectivity for epoch 23
#     computing connectivity for epoch 24
#     computing connectivity for epoch 25
#     assembling connectivity matrix (filling the upper triangular region of the matrix)
# [Connectivity computation done]
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 435 connections
#     using t=1.100s..1.300s for estimation (201 points)
#     frequencies: 5.0Hz..5.0Hz (1 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing connectivity for epoch 1
#     computing connectivity for epoch 2
#     computing connectivity for epoch 3
#     computing connectivity for epoch 4
#     computing connectivity for epoch 5
#     computing connectivity for epoch 6
#     computing connectivity for epoch 7
#     computing connectivity for epoch 8
#     computing connectivity for epoch 9
#     computing connectivity for epoch 10
#     computing connectivity for epoch 11
#     computing connectivity for epoch 12
#     computing connectivity for epoch 13
#     computing connectivity for epoch 14
#     computing connectivity for epoch 15
#     computing connectivity for epoch 16
#     computing connectivity for epoch 17
#     computing connectivity for epoch 18
#     computing connectivity for epoch 19
#     computing connectivity for epoch 20
#     computing connectivity for epoch 21
#     computing connectivity for epoch 22
#     computing connectivity for epoch 23
#     computing connectivity for epoch 24
#     computing connectivity for epoch 25
#     assembling connectivity matrix (filling the upper triangular region of the matrix)
# [Connectivity computation done]
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 435 connections
#     using t=1.300s..1.500s for estimation (201 points)
#     frequencies: 5.0Hz..5.0Hz (1 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing connectivity for epoch 1
#     computing connectivity for epoch 2
#     computing connectivity for epoch 3
#     computing connectivity for epoch 4
#     computing connectivity for epoch 5
#     computing connectivity for epoch 6
#     computing connectivity for epoch 7
#     computing connectivity for epoch 8
#     computing connectivity for epoch 9
#     computing connectivity for epoch 10
#     computing connectivity for epoch 11
#     computing connectivity for epoch 12
# <ipython-input-5-c085383cba6a>:74: RuntimeWarning: fmin=4.000 Hz corresponds to 0.804 < 5 cycles based on the epoch length 0.201 sec, need at least 1.250 sec epochs or fmin=24.876. Spectrum estimate will be unreliable.
#   faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
# <ipython-input-5-c085383cba6a>:86: RuntimeWarning: fmin=4.000 Hz corresponds to 0.804 < 5 cycles based on the epoch length 0.201 sec, need at least 1.250 sec epochs or fmin=24.876. Spectrum estimate will be unreliable.
#   faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
#     computing connectivity for epoch 13
#     computing connectivity for epoch 14
#     computing connectivity for epoch 15
#     computing connectivity for epoch 16
#     computing connectivity for epoch 17
#     computing connectivity for epoch 18
#     computing connectivity for epoch 19
#     computing connectivity for epoch 20
#     computing connectivity for epoch 21
#     computing connectivity for epoch 22
#     computing connectivity for epoch 23
#     computing connectivity for epoch 24
#     computing connectivity for epoch 25
#     assembling connectivity matrix (filling the upper triangular region of the matrix)
# [Connectivity computation done]
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 435 connections
#     using t=0.300s..0.500s for estimation (201 points)
#     frequencies: 10.0Hz..10.0Hz (1 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing connectivity for epoch 1
#     computing connectivity for epoch 2
#     computing connectivity for epoch 3
#     computing connectivity for epoch 4
#     computing connectivity for epoch 5
#     computing connectivity for epoch 6
#     computing connectivity for epoch 7
#     computing connectivity for epoch 8
#     computing connectivity for epoch 9
#     computing connectivity for epoch 10
#     computing connectivity for epoch 11
#     computing connectivity for epoch 12
#     computing connectivity for epoch 13
#     computing connectivity for epoch 14
#     computing connectivity for epoch 15
#     computing connectivity for epoch 16
#     computing connectivity for epoch 17
#     computing connectivity for epoch 18
#     computing connectivity for epoch 19
#     computing connectivity for epoch 20
#     computing connectivity for epoch 21
#     computing connectivity for epoch 22
#     computing connectivity for epoch 23
#     computing connectivity for epoch 24
#     computing connectivity for epoch 25
#     assembling connectivity matrix (filling the upper triangular region of the matrix)
# [Connectivity computation done]
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 435 connections
#     using t=0.500s..0.700s for estimation (201 points)
#     frequencies: 10.0Hz..10.0Hz (1 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing connectivity for epoch 1
#     computing connectivity for epoch 2
#     computing connectivity for epoch 3
#     computing connectivity for epoch 4
#     computing connectivity for epoch 5
#     computing connectivity for epoch 6
#     computing connectivity for epoch 7
#     computing connectivity for epoch 8
#     computing connectivity for epoch 9
#     computing connectivity for epoch 10
#     computing connectivity for epoch 11
#     computing connectivity for epoch 12
#     computing connectivity for epoch 13
#     computing connectivity for epoch 14
#     computing connectivity for epoch 15
#     computing connectivity for epoch 16
#     computing connectivity for epoch 17
# <ipython-input-5-c085383cba6a>:105: RuntimeWarning: fmin=8.000 Hz corresponds to 1.608 < 5 cycles based on the epoch length 0.201 sec, need at least 0.625 sec epochs or fmin=24.876. Spectrum estimate will be unreliable.
#   faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
# <ipython-input-5-c085383cba6a>:116: RuntimeWarning: fmin=8.000 Hz corresponds to 1.608 < 5 cycles based on the epoch length 0.201 sec, need at least 0.625 sec epochs or fmin=24.876. Spectrum estimate will be unreliable.
#   faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
#     computing connectivity for epoch 18
#     computing connectivity for epoch 19
#     computing connectivity for epoch 20
#     computing connectivity for epoch 21
#     computing connectivity for epoch 22
#     computing connectivity for epoch 23
#     computing connectivity for epoch 24
#     computing connectivity for epoch 25
#     assembling connectivity matrix (filling the upper triangular region of the matrix)
# [Connectivity computation done]
# Connectivity computation...
# ...
#     computing connectivity for epoch 4
# <ipython-input-5-c085383cba6a>:128: RuntimeWarning: fmin=8.000 Hz corresponds to 1.608 < 5 cycles based on the epoch length 0.201 sec, need at least 0.625 sec epochs or fmin=24.876. Spectrum estimate will be unreliable.
#   faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
# <ipython-input-5-c085383cba6a>:140: RuntimeWarning: fmin=8.000 Hz corresponds to 1.608 < 5 cycles based on the epoch length 0.201 sec, need at least 0.625 sec epochs or fmin=24.876. Spectrum estimate will be unreliable.
#   faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
#     computing connectivity for epoch 5
#     computing connectivity for epoch 6
#     computing connectivity for epoch 7
#     computing connectivity for epoch 8
#     computing connectivity for epoch 9
#     computing connectivity for epoch 10
#     computing connectivity for epoch 11
#     computing connectivity for epoch 12
#     computing connectivity for epoch 13
#     computing connectivity for epoch 14
#     computing connectivity for epoch 15
#     computing connectivity for epoch 16
#     computing connectivity for epoch 17
#     computing connectivity for epoch 18
#     computing connectivity for epoch 19
#     computing connectivity for epoch 20
#     computing connectivity for epoch 21
#     computing connectivity for epoch 22
#     computing connectivity for epoch 23
#     computing connectivity for epoch 24
#     computing connectivity for epoch 25
#     assembling connectivity matrix (filling the upper triangular region of the matrix)
# [Connectivity computation done]
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 435 connections
#     using t=1.100s..1.300s for estimation (201 points)
#     frequencies: 10.0Hz..10.0Hz (1 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing connectivity for epoch 1
#     computing connectivity for epoch 2
#     computing connectivity for epoch 3
#     computing connectivity for epoch 4
#     computing connectivity for epoch 5
#     computing connectivity for epoch 6
#     computing connectivity for epoch 7
#     computing connectivity for epoch 8
#     computing connectivity for epoch 9
#     computing connectivity for epoch 10
#     computing connectivity for epoch 11
#     computing connectivity for epoch 12
#     computing connectivity for epoch 13
#     computing connectivity for epoch 14
#     computing connectivity for epoch 15
#     computing connectivity for epoch 16
#     computing connectivity for epoch 17
#     computing connectivity for epoch 18
#     computing connectivity for epoch 19
#     computing connectivity for epoch 20
#     computing connectivity for epoch 21
#     computing connectivity for epoch 22
#     computing connectivity for epoch 23
#     computing connectivity for epoch 24
#     computing connectivity for epoch 25
#     assembling connectivity matrix (filling the upper triangular region of the matrix)
# [Connectivity computation done]
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 435 connections
#     using t=1.300s..1.500s for estimation (201 points)
#     frequencies: 10.0Hz..10.0Hz (1 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing connectivity for epoch 1
#     computing connectivity for epoch 2
#     computing connectivity for epoch 3
#     computing connectivity for epoch 4
#     computing connectivity for epoch 5
#     computing connectivity for epoch 6
#     computing connectivity for epoch 7
#     computing connectivity for epoch 8
#     computing connectivity for epoch 9
#     computing connectivity for epoch 10
#     computing connectivity for epoch 11
#     computing connectivity for epoch 12
# <ipython-input-5-c085383cba6a>:151: RuntimeWarning: fmin=8.000 Hz corresponds to 1.608 < 5 cycles based on the epoch length 0.201 sec, need at least 0.625 sec epochs or fmin=24.876. Spectrum estimate will be unreliable.
#   faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
# <ipython-input-5-c085383cba6a>:162: RuntimeWarning: fmin=8.000 Hz corresponds to 1.608 < 5 cycles based on the epoch length 0.201 sec, need at least 0.625 sec epochs or fmin=24.876. Spectrum estimate will be unreliable.
#   faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
#     computing connectivity for epoch 13
#     computing connectivity for epoch 14
#     computing connectivity for epoch 15
#     computing connectivity for epoch 16
#     computing connectivity for epoch 17
#     computing connectivity for epoch 18
#     computing connectivity for epoch 19
#     computing connectivity for epoch 20
#     computing connectivity for epoch 21
#     computing connectivity for epoch 22
#     computing connectivity for epoch 23
#     computing connectivity for epoch 24
#     computing connectivity for epoch 25
#     assembling connectivity matrix (filling the upper triangular region of the matrix)
# [Connectivity computation done]
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 435 connections
#     using t=0.300s..0.500s for estimation (201 points)
#     frequencies: 14.9Hz..29.9Hz (4 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing connectivity for epoch 1
#     computing connectivity for epoch 2
#     computing connectivity for epoch 3
#     computing connectivity for epoch 4
#     computing connectivity for epoch 5
#     computing connectivity for epoch 6
#     computing connectivity for epoch 7
#     computing connectivity for epoch 8
#     computing connectivity for epoch 9
#     computing connectivity for epoch 10
#     computing connectivity for epoch 11
#     computing connectivity for epoch 12
#     computing connectivity for epoch 13
#     computing connectivity for epoch 14
#     computing connectivity for epoch 15
#     computing connectivity for epoch 16
#     computing connectivity for epoch 17
#     computing connectivity for epoch 18
#     computing connectivity for epoch 19
#     computing connectivity for epoch 20
#     computing connectivity for epoch 21
#     computing connectivity for epoch 22
#     computing connectivity for epoch 23
#     computing connectivity for epoch 24
#     computing connectivity for epoch 25
#     assembling connectivity matrix (filling the upper triangular region of the matrix)
# [Connectivity computation done]
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 435 connections
#     using t=0.500s..0.700s for estimation (201 points)
#     frequencies: 14.9Hz..29.9Hz (4 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing connectivity for epoch 1
#     computing connectivity for epoch 2
#     computing connectivity for epoch 3
#     computing connectivity for epoch 4
# <ipython-input-5-c085383cba6a>:179: RuntimeWarning: fmin=14.000 Hz corresponds to 2.814 < 5 cycles based on the epoch length 0.201 sec, need at least 0.357 sec epochs or fmin=24.876. Spectrum estimate will be unreliable.
#   faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
# <ipython-input-5-c085383cba6a>:190: RuntimeWarning: fmin=14.000 Hz corresponds to 2.814 < 5 cycles based on the epoch length 0.201 sec, need at least 0.357 sec epochs or fmin=24.876. Spectrum estimate will be unreliable.
#   faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
#     computing connectivity for epoch 5
#     computing connectivity for epoch 6
#     computing connectivity for epoch 7
#     computing connectivity for epoch 8
#     computing connectivity for epoch 9
#     computing connectivity for epoch 10
#     computing connectivity for epoch 11
#     computing connectivity for epoch 12
#     computing connectivity for epoch 13
#     computing connectivity for epoch 14
#     computing connectivity for epoch 15
#     computing connectivity for epoch 16
#     computing connectivity for epoch 17
#     computing connectivity for epoch 18
#     computing connectivity for epoch 19
#     computing connectivity for epoch 20
#     computing connectivity for epoch 21
#     computing connectivity for epoch 22
#     computing connectivity for epoch 23
#     computing connectivity for epoch 24
#     computing connectivity for epoch 25
#     assembling connectivity matrix (filling the upper triangular region of the matrix)
# [Connectivity computation done]
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 435 connections
#     using t=0.700s..0.900s for estimation (201 points)
#     frequencies: 14.9Hz..29.9Hz (4 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing connectivity for epoch 1
#     computing connectivity for epoch 2
#     computing connectivity for epoch 3
#     computing connectivity for epoch 4
#     computing connectivity for epoch 5
#     computing connectivity for epoch 6
#     computing connectivity for epoch 7
#     computing connectivity for epoch 8
#     computing connectivity for epoch 9
#     computing connectivity for epoch 10
#     computing connectivity for epoch 11
#     computing connectivity for epoch 12
#     computing connectivity for epoch 13
#     computing connectivity for epoch 14
#     computing connectivity for epoch 15
#     computing connectivity for epoch 16
#     computing connectivity for epoch 17
#     computing connectivity for epoch 18
#     computing connectivity for epoch 19
#     computing connectivity for epoch 20
#     computing connectivity for epoch 21
#     computing connectivity for epoch 22
#     computing connectivity for epoch 23
#     computing connectivity for epoch 24
#     computing connectivity for epoch 25
#     assembling connectivity matrix (filling the upper triangular region of the matrix)
# [Connectivity computation done]
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 435 connections
#     using t=0.900s..1.100s for estimation (201 points)
#     frequencies: 14.9Hz..29.9Hz (4 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing connectivity for epoch 1
#     computing connectivity for epoch 2
#     computing connectivity for epoch 3
#     computing connectivity for epoch 4
#     computing connectivity for epoch 5
#     computing connectivity for epoch 6
# <ipython-input-5-c085383cba6a>:201: RuntimeWarning: fmin=14.000 Hz corresponds to 2.814 < 5 cycles based on the epoch length 0.201 sec, need at least 0.357 sec epochs or fmin=24.876. Spectrum estimate will be unreliable.
#   faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
# <ipython-input-5-c085383cba6a>:212: RuntimeWarning: fmin=14.000 Hz corresponds to 2.814 < 5 cycles based on the epoch length 0.201 sec, need at least 0.357 sec epochs or fmin=24.876. Spectrum estimate will be unreliable.
#   faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
#     computing connectivity for epoch 7
#     computing connectivity for epoch 8
#     computing connectivity for epoch 9
#     computing connectivity for epoch 10
#     computing connectivity for epoch 11
#     computing connectivity for epoch 12
#     computing connectivity for epoch 13
#     computing connectivity for epoch 14
#     computing connectivity for epoch 15
#     computing connectivity for epoch 16
#     computing connectivity for epoch 17
#     computing connectivity for epoch 18
#     computing connectivity for epoch 19
#     computing connectivity for epoch 20
#     computing connectivity for epoch 21
#     computing connectivity for epoch 22
#     computing connectivity for epoch 23
#     computing connectivity for epoch 24
#     computing connectivity for epoch 25
#     assembling connectivity matrix (filling the upper triangular region of the matrix)
# [Connectivity computation done]
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 435 connections
#     using t=1.100s..1.300s for estimation (201 points)
#     frequencies: 14.9Hz..29.9Hz (4 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing connectivity for epoch 1
#     computing connectivity for epoch 2
#     computing connectivity for epoch 3
#     computing connectivity for epoch 4
#     computing connectivity for epoch 5
#     computing connectivity for epoch 6
#     computing connectivity for epoch 7
#     computing connectivity for epoch 8
#     computing connectivity for epoch 9
#     computing connectivity for epoch 10
#     computing connectivity for epoch 11
#     computing connectivity for epoch 12
#     computing connectivity for epoch 13
#     computing connectivity for epoch 14
#     computing connectivity for epoch 15
#     computing connectivity for epoch 16
#     computing connectivity for epoch 17
#     computing connectivity for epoch 18
#     computing connectivity for epoch 19
#     computing connectivity for epoch 20
#     computing connectivity for epoch 21
#     computing connectivity for epoch 22
#     computing connectivity for epoch 23
#     computing connectivity for epoch 24
#     computing connectivity for epoch 25
#     assembling connectivity matrix (filling the upper triangular region of the matrix)
# [Connectivity computation done]
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 435 connections
#     using t=1.300s..1.500s for estimation (201 points)
#     frequencies: 14.9Hz..29.9Hz (4 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: Debiased WPLI Square
#     computing connectivity for epoch 1
# <ipython-input-5-c085383cba6a>:223: RuntimeWarning: fmin=14.000 Hz corresponds to 2.814 < 5 cycles based on the epoch length 0.201 sec, need at least 0.357 sec epochs or fmin=24.876. Spectrum estimate will be unreliable.
#   faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
# <ipython-input-5-c085383cba6a>:234: RuntimeWarning: fmin=14.000 Hz corresponds to 2.814 < 5 cycles based on the epoch length 0.201 sec, need at least 0.357 sec epochs or fmin=24.876. Spectrum estimate will be unreliable.
#   faverage=True, tmin=tmin, tmax=tmax, mt_adaptive=False, n_jobs=1)
#     computing connectivity for epoch 2
#     computing connectivity for epoch 3
#     computing connectivity for epoch 4
#     computing connectivity for epoch 5
#     computing connectivity for epoch 6
#     computing connectivity for epoch 7
#     computing connectivity for epoch 8
#     computing connectivity for epoch 9
#     computing connectivity for epoch 10
#     computing connectivity for epoch 11
#     computing connectivity for epoch 12
#     computing connectivity for epoch 13
#     computing connectivity for epoch 14
#     computing connectivity for epoch 15
#     computing connectivity for epoch 16
#     computing connectivity for epoch 17
#     computing connectivity for epoch 18
#     computing connectivity for epoch 19
#     computing connectivity for epoch 20
#     computing connectivity for epoch 21
#     computing connectivity for epoch 22
#     computing connectivity for epoch 23
#     computing connectivity for epoch 24
#     computing connectivity for epoch 25
#     assembling connectivity matrix (filling the upper triangular region of the matrix)
# [Connectivity computation done]
