# %%
# %matplotlib inline

import os.path as op
import numpy as np
import matplotlib.pyplot as plt
from scipy import linalg

import mne
from mne.time_frequency import tfr_morlet, psd_multitaper
from mne.connectivity import spectral_connectivity

import csv

# %%
data_path = "/Users/emi/Desktop/media_TBS/media2/adj_tv/"

N = 12
IDs_exp = ('male01_tv_adj','male02_tv_adj','male03_tv_adj','male04_tv_adj','male05_tv_adj','male06_tv_adj','male07_tv_adj','male08_tv_adj','male09_tv_adj','male10_tv_adj','male11_tv_adj','male12_tv_adj')

S1= "S1"
BAS = "_Nbas"

p_threshold = 0.01

# %%
S1_theta000_exp = np.array([[0,0,0], [28, 28, N]])
S1_theta200_exp = np.array([[0,0,0], [28, 28, N]])
S1_theta400_exp = np.array([[0,0,0],  [28, 28, N]])
S1_theta600_exp = np.array([[0,0,0],  [28, 28, N]])
S1_theta800_exp = np.array([[0,0,0],  [28, 28, N]])
BAS_theta000_exp = np.array([[0,0,0],  [28, 28, N]])

S1_alpha000_exp = np.array([[0,0,0],  [28, 28, N]])
S1_alpha200_exp = np.array([[0,0,0],  [28, 28, N]])
S1_alpha400_exp = np.array([[0,0,0],  [28, 28, N]])
S1_alpha600_exp = np.array([[0,0,0],  [28, 28, N]])
S1_alpha800_exp = np.array([[0,0,0],  [28, 28, N]])
BAS_alpha000_exp = np.array([[0,0,0],  [28, 28, N]])

S1_beta000_exp = np.array([[0,0,0],  [28, 28, N]])
S1_beta200_exp = np.array([[0,0,0],  [28, 28, N]])
S1_beta400_exp = np.array([[0,0,0],  [28, 28, N]])
S1_beta600_exp = np.array([[0,0,0],  [28, 28, N]])
S1_beta700_exp = np.array([[0,0,0],  [28, 28, N]])
BAS_beta000_exp = np.array([[0,0,0],  [28, 28, N]])

# %%
ch_names = ('Fp1', 'Fz', 'F3', 'F7', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'Pz', 'P3', 'P7', 'O1', 'Oz', 'O2', 'P4', 'P8', 'CP6', 'CP2', 'Cz', 'C4', 'T8', 'FC6', 'FC2', 'F4', 'F8', 'Fp2')

# %%
median_S1_theta000_exp = np.array([[0,0], [28, 28]])
median_S1_theta200_exp = np.array([[0,0], [28, 28]])
median_S1_theta400_exp = np.array([[0,0], [28, 28]])
median_S1_theta600_exp =np.array([[0,0], [28, 28]])
median_S1_theta800_exp = np.array([[0,0], [28, 28]])
median_BAS_theta000_exp =np.array([[0,0], [28, 28]])

p_theta000_exp = np.array([[0,0], [28, 28]])
p_theta200_exp =np.array([[0,0], [28, 28]])
p_theta400_exp = np.array([[0,0], [28, 28]])
p_theta600_exp = np.array([[0,0], [28, 28]])
p_theta800_exp = np.array([[0,0], [28, 28]])

p_theta000_sig_exp =np.array([[0,0], [28, 28]])
p_theta200_sig_exp = np.array([[0,0], [28, 28]])
p_theta400_sig_exp = np.array([[0,0], [28, 28]])
p_theta600_sig_exp = np.array([[0,0], [28, 28]])
p_theta800_sig_exp = np.array([[0,0], [28, 28]])

p_theta000_adj_exp = np.array([[0,0], [28, 28]])
p_theta200_adj_exp = np.array([[0,0], [28, 28]])
p_theta400_adj_exp = np.array([[0,0], [28, 28]])
p_theta600_adj_exp = np.array([[0,0], [28, 28]])
p_theta800_adj_exp = np.array([[0,0], [28, 28]])

median_theta000_exp = np.array([[0,0], [28, 28]])
median_theta200_exp = np.array([[0,0], [28, 28]])
median_theta400_exp = np.array([[0,0], [28, 28]])
median_theta600_exp = np.array([[0,0], [28, 28]])
median_theta800_exp = np.array([[0,0], [28, 28]])

# %%
median_S1_alpha000_exp = np.array([[0,0], [28, 28]])
median_S1_alpha200_exp = np.array([[0,0], [28, 28]])
median_S1_alpha400_exp = np.array([[0,0], [28, 28]])
median_S1_alpha600_exp =np.array([[0,0], [28, 28]])
median_S1_alpha800_exp = np.array([[0,0], [28, 28]])
median_BAS_alpha000_exp =np.array([[0,0], [28, 28]])

p_alpha000_exp = np.array([[0,0], [28, 28]])
p_alpha200_exp =np.array([[0,0], [28, 28]])
p_alpha400_exp = np.array([[0,0], [28, 28]])
p_alpha600_exp = np.array([[0,0], [28, 28]])
p_alpha800_exp = np.array([[0,0], [28, 28]])

p_alpha000_sig_exp =np.array([[0,0], [28, 28]])
p_alpha200_sig_exp = np.array([[0,0], [28, 28]])
p_alpha400_sig_exp = np.array([[0,0], [28, 28]])
p_alpha600_sig_exp = np.array([[0,0], [28, 28]])
p_alpha800_sig_exp = np.array([[0,0], [28, 28]])

p_alpha000_adj_exp = np.array([[0,0], [28, 28]])
p_alpha200_adj_exp = np.array([[0,0], [28, 28]])
p_alpha400_adj_exp = np.array([[0,0], [28, 28]])
p_alpha600_adj_exp = np.array([[0,0], [28, 28]])
p_alpha800_adj_exp = np.array([[0,0], [28, 28]])

median_alpha000_exp = np.array([[0,0], [28, 28]])
median_alpha200_exp = np.array([[0,0], [28, 28]])
median_alpha400_exp = np.array([[0,0], [28, 28]])
median_alpha600_exp = np.array([[0,0], [28, 28]])
median_alpha800_exp = np.array([[0,0], [28, 28]])

# %%
median_S1_beta000_exp = np.array([[0,0], [28, 28]])
median_S1_beta200_exp = np.array([[0,0], [28, 28]])
median_S1_beta400_exp = np.array([[0,0], [28, 28]])
median_S1_beta600_exp =np.array([[0,0], [28, 28]])
median_S1_beta800_exp = np.array([[0,0], [28, 28]])
median_BAS_beta000_exp =np.array([[0,0], [28, 28]])

p_beta000_exp = np.array([[0,0], [28, 28]])
p_beta200_exp =np.array([[0,0], [28, 28]])
p_beta400_exp = np.array([[0,0], [28, 28]])
p_beta600_exp = np.array([[0,0], [28, 28]])
p_beta800_exp = np.array([[0,0], [28, 28]])

p_beta000_sig_exp =np.array([[0,0], [28, 28]])
p_beta200_sig_exp = np.array([[0,0], [28, 28]])
p_beta400_sig_exp = np.array([[0,0], [28, 28]])
p_beta600_sig_exp = np.array([[0,0], [28, 28]])
p_beta800_sig_exp = np.array([[0,0], [28, 28]])

p_beta000_adj_exp = np.array([[0,0], [28, 28]])
p_beta200_adj_exp = np.array([[0,0], [28, 28]])
p_beta400_adj_exp = np.array([[0,0], [28, 28]])
p_beta600_adj_exp = np.array([[0,0], [28, 28]])
p_beta800_adj_exp = np.array([[0,0], [28, 28]])

median_beta000_exp = np.array([[0,0], [28, 28]])
median_beta200_exp = np.array([[0,0], [28, 28]])
median_beta400_exp = np.array([[0,0], [28, 28]])
median_beta600_exp = np.array([[0,0], [28, 28]])
median_beta800_exp = np.array([[0,0], [28, 28]])

# %%
for i in range(1, 28):
    for j in range(1,28):
        if S1_theta000_exp[i,j,1] == 0:
            median_S1_theta000_exp[i,j] = 0
            median_S1_theta200_exp[i,j] = 0
            median_S1_theta400_exp[i,j] = 0
            median_S1_theta600_exp[i,j] = 0
            median_S1_theta800_exp[i,j] = 0
            median_BAS_theta000_exp[i,j] = 0
            
            p_theta000_exp[i,j] = 0
            p_theta200_exp[i,j] = 0
            p_theta400_exp[i,j] = 0
            p_theta600_exp[i,j] = 0
            p_theta800_exp[i,j] = 0
            
        else:
            
            median_S1_theta000_exp[i,j] = median(S1_theta000_exp[i,j])
            median_S1_theta200_exp[i,j] = median(S1_theta200_exp[i,j])
            median_S1_theta400_exp[i,j] = median(S1_theta400_exp[i,j])
            median_S1_theta600_exp[i,j] = median(S1_theta600_exp[i,j])
            median_S1_theta800_exp[i,j] = median(S1_theta800_exp[i,j])
            median_BAS_theta000_exp[i,j] = median(BAS_theta000_exp[i,j])
       
            median_theta000_exp[i,j] =  median_S1_theta000_exp[i,j] - median_BAS_theta000_exp[i,j]
            median_theta200_exp[i,j] =  median_S1_theta200_exp[i,j] - median_BAS_theta000_exp[i,j]
            median_theta400_exp[i,j] =  median_S1_theta400_exp[i,j] - median_BAS_theta000_exp[i,j]
            median_theta600_exp[i,j] =  median_S1_theta600_exp[i,j] - median_BAS_theta000_exp[i,j]
            median_theta800_exp[i,j] =  median_S1_theta800_exp[i,j] - median_BAS_theta000_exp[i,j]
            
            p_theta000_exp[i,j] = statistics.median(S1_theta000_exp[i,j,],BAS_theta000_exp[i,j])#p.value
            p_theta200_exp[i,j] = statistics.median(S1_theta200_exp[i,j],BAS_theta000_exp[i,j])#p.value
            p_theta400_exp[i,j] = statistics.median(S1_theta400_exp[i,j],BAS_theta000_exp[i,j])#p.value
            p_theta600_exp[i,j] = statistics.median(S1_theta600_exp[i,j],BAS_theta000_exp[i,j])#p.value
            p_theta800_exp[i,j] = statistics.median(S1_theta800_exp[i,j],BAS_theta000_exp[i,j])#p.value
       
        p_theta000_adj_exp[i, j] = np.array([p_theta000_exp, 28,28])

for i in range(1, 28):
    for j in range(1,28):
           if isnull(p_theta000_adj_exp[i,j]):
                          p_theta000_sig_exp[i, j] = [0,0] 

        elif  p_theta000_adj_exp[i, j] < p_threshold:
            p_theta000_sig_exp[i, j] = median_S1_theta000_exp[i,j] - median_BAS_theta000_exp[i,j]
        else:
                   p_theta000_sig_exp[i, j] = [0,0]
# Out:
#   File "<ipython-input-12-9ca187d59201>", line 45
#     elif  p_theta000_adj_exp[i, j] < p_threshold:
#                                                  ^
# IndentationError: unindent does not match any outer indentation level

# %%
for i in range(1, 28):
    for j in range(1,28):
        if S1_alp000_exp[i,j,1] == 0:
            median_S1_alpha000_exp[i,j] = 0
            median_S1_alpha200_exp[i,j] = 0
            median_S1_alpha400_exp[i,j] = 0
            median_S1_alpha600_exp[i,j] = 0
            median_S1_alpha800_exp[i,j] = 0
            median_BAS_alpha000_exp[i,j] = 0
            
            p_alpha000_exp[i,j] = 0
            p_alpha200_exp[i,j] = 0
            p_alpha400_exp[i,j] = 0
            p_alpha600_exp[i,j] = 0
            p_alpha800_exp[i,j] = 0
            
        else:
            
            median_S1_alpha000_exp[i,j] = median(S1_alpha000_exp[i,j])
            median_S1_alpha200_exp[i,j] = median(S1_alpha200_exp[i,j])
            median_S1_alpha400_exp[i,j] = median(S1_alpha400_exp[i,j])
            median_S1_alpha600_exp[i,j] = median(S1_alpha600_exp[i,j])
            median_S1_alpha800_exp[i,j] = median(S1_alpha800_exp[i,j])
            median_BAS_alpha000_exp[i,j] = median(BAS_alpha000_exp[i,j])
       
            median_alpha000_exp[i,j] =  median_S1_alpha000_exp[i,j] - median_BAS_alpha000_exp[i,j]
            median_alpha200_exp[i,j] =  median_S1_alpha200_exp[i,j] - median_BAS_alpha000_exp[i,j]
            median_alpha400_exp[i,j] =  median_S1_alpha400_exp[i,j] - median_BAS_alpha000_exp[i,j]
            median_alpha600_exp[i,j] =  median_S1_alpha600_exp[i,j] - median_BAS_alpha000_exp[i,j]
            median_alpha800_exp[i,j] =  median_S1_alpha800_exp[i,j] - median_BAS_alpha000_exp[i,j]
            
            p_alpha000_exp[i,j] = statistics.median(S1_alpha000_exp[i,j,],BAS_alpha000_exp[i,j])#p.value
            p_alpha200_exp[i,j] = statistics.median(S1_alpha200_exp[i,j],BAS_alpha000_exp[i,j])#p.value
            p_alpha400_exp[i,j] = statistics.median(S1_alpha400_exp[i,j],BAS_alpha000_exp[i,j])#p.value
            p_alpha600_exp[i,j] = statistics.median(S1_alpha600_exp[i,j],BAS_alpha000_exp[i,j])#p.value
            p_alpha800_exp[i,j] = statistics.median(S1_alpha800_exp[i,j],BAS_alpha000_exp[i,j])#p.value
       
        p_theta000_adj_exp[i, j] = np.array([p_theta000_exp, 28,28])

for i in range(1, 28):
    for j in range(1,28):
           if isnull(p_alpha000_adj_exp[i,j]):
                          p_alpha000_sig_exp[i, j] = [0,0] 

        elif  p_alpha000_adj_exp[i, j] < p_threshold:
            p_alpha000_sig_exp[i, j] = median_S1_alpha000_exp[i,j] - median_BAS_alpha000_exp[i,j]
        else:
                   p_theta000_sig_exp[i, j] = [0,0]

# %%
for i in range(1, 28):
    for j in range(1,28):
        if S1_theta000_exp[i,j,1] == 0:
            median_S1_theta000_exp[i,j] = 0
            median_S1_theta200_exp[i,j] = 0
            median_S1_theta400_exp[i,j] = 0
            median_S1_theta600_exp[i,j] = 0
            median_S1_theta800_exp[i,j] = 0
            median_BAS_theta000_exp[i,j] = 0
            
            p_theta000_exp[i,j] = 0
            p_theta200_exp[i,j] = 0
            p_theta400_exp[i,j] = 0
            p_theta600_exp[i,j] = 0
            p_theta800_exp[i,j] = 0
            
        else:
            
            median_S1_theta000_exp[i,j] = median(S1_theta000_exp[i,j])
            median_S1_theta200_exp[i,j] = median(S1_theta200_exp[i,j])
            median_S1_theta400_exp[i,j] = median(S1_theta400_exp[i,j])
            median_S1_theta600_exp[i,j] = median(S1_theta600_exp[i,j])
            median_S1_theta800_exp[i,j] = median(S1_theta800_exp[i,j])
            median_BAS_theta000_exp[i,j] = median(BAS_theta000_exp[i,j])
       
            median_theta000_exp[i,j] =  median_S1_theta000_exp[i,j] - median_BAS_theta000_exp[i,j]
            median_theta200_exp[i,j] =  median_S1_theta200_exp[i,j] - median_BAS_theta000_exp[i,j]
            median_theta400_exp[i,j] =  median_S1_theta400_exp[i,j] - median_BAS_theta000_exp[i,j]
            median_theta600_exp[i,j] =  median_S1_theta600_exp[i,j] - median_BAS_theta000_exp[i,j]
            median_theta800_exp[i,j] =  median_S1_theta800_exp[i,j] - median_BAS_theta000_exp[i,j]
            
            p_theta000_exp[i,j] = statistics.median(S1_theta000_exp[i,j,],BAS_theta000_exp[i,j])#p.value
            p_theta200_exp[i,j] = statistics.median(S1_theta200_exp[i,j],BAS_theta000_exp[i,j])#p.value
            p_theta400_exp[i,j] = statistics.median(S1_theta400_exp[i,j],BAS_theta000_exp[i,j])#p.value
            p_theta600_exp[i,j] = statistics.median(S1_theta600_exp[i,j],BAS_theta000_exp[i,j])#p.value
            p_theta800_exp[i,j] = statistics.median(S1_theta800_exp[i,j],BAS_theta000_exp[i,j])#p.value
       
        p_theta000_adj_exp[i, j] = np.array([p_theta000_exp, 28,28])

for i in range(1, 30):
    for j in range(1,30):
           if isnull(p_theta000_adj_exp[i,j]):
                          p_theta000_sig_exp[i, j] = [0,0] 

        elif  p_theta000_adj_exp[i, j] < p_threshold:
            p_theta000_sig_exp[i, j] = median_S1_theta000_exp[i,j] - median_BAS_theta000_exp[i,j]
        else:
                   p_theta000_sig_exp[i, j] = [0,0]
