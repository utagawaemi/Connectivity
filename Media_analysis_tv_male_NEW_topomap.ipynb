# %%
import numpy as np
import matplotlib.pyplot as plt
import os.path as op

import mne
#from mne.datasets import sample
from mne.minimum_norm import (make_inverse_operator, apply_inverse,
                              write_inverse_operator)

from mne.preprocessing import create_eog_epochs
from mne.viz import plot_evoked_topo

import scipy
from mayavi import mlab
# %gui qt

# sphinx_gallery_thumbnail_number = 9

# %%
data_path = '/Users/emi/Desktop/media_TBS/mod_tv/'
#data_path = '/Users/risashimizu/Desktop/media/media2/adj_rest/'
cname = 'male'
sname = '_tv_mod'
#sname = '01_rest_adj'    #被験者数は女子12人、男子１２人
hname =  '.set'

# %%
mon = mne.channels.read_montage(kind = 'standard_1020')

#01
fname01 = data_path + cname + '01' + sname + hname

events01 = mne.io.read_events_eeglab('/Users/emi/Desktop/media_TBS/mod_tv/male01_tv_mod.set')
aw01 = mne.io.read_epochs_eeglab(fname01,
                               montage=mon,
                               eog=('EOG1', 'EOG2'),
                               events=events01,
                               event_id = {'TV1':1, 'TV2':2, 'TV3':3, 'TV4':4, 'TV5':5, 'TV6':6, 'TV7':7, 'TV8':8, 'TV9':9, 'TV10':10, 'TV11':11, 'TV12':12, 'TV13':13, 'TV14':14, 'TV15':15, 'TV16':16, 'TV17':17, 'TV18':18, 'TV19':19, 'TV20':20, 'TV21':21,'TV22':22, 'TV23':23, 'TV24':24, 'TV25':25})

aw01.set_channel_types({'EOG1': 'eog', 'EOG2': 'eog'}) # Set Channel Type(それぞれを区別、名前をつける)
aw01.set_eeg_reference('average',projection=True)

picks01 = mne.pick_types(aw01.info, meg=False, eeg=True, eog=False, stim=False)  #読み込むチャンネルを設定
# Out:
# Extracting parameters from /Users/emi/Desktop/media_TBS/mod_tv/male01_tv_mod.set...
# /Users/emi/.pyenv/versions/anaconda2-4.2.0/lib/python2.7/site-packages/mne/utils.py:876: DeprecationWarning: Function read_events_eeglab is deprecated; read_events_eeglab is deprecated from 0.17 and will be removed in 0.18. Please use read_annotations and create events using events_from_annotations.
#   warnings.warn(msg, category=DeprecationWarning)
# 25 matching events found
# No baseline correction applied
# Not setting metadata
# 0 projection items activated
# Ready.
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.

# %%
#02
fname02 = data_path + cname + '02' + sname + hname

events02 = mne.io.read_events_eeglab('/Users/emi/Desktop/media_TBS/mod_tv/male02_tv_mod.set')
            
aw02 = mne.io.read_epochs_eeglab(fname02,montage=mon,
                               eog=('EOG1', 'EOG2'),
                               events=events02,
                               event_id = {'TV1':1, 'TV2':2, 'TV3':3, 'TV4':4, 'TV5':5, 'TV6':6, 'TV7':7, 'TV8':8, 'TV9':9, 'TV10':10, 'TV11':11, 'TV12':12, 'TV13':13, 'TV14':14, 'TV15':15, 'TV16':16, 'TV17':17, 'TV18':18, 'TV19':19, 'TV20':20, 'TV21':21,'TV22':22, 'TV23':23, 'TV24':24, 'TV25':25})
aw02.set_channel_types({'EOG1': 'eog', 'EOG2': 'eog'}) # Set Channel Type(それぞれを区別、名前をつける)
aw02.set_eeg_reference('average',projection=True)

picks02 = mne.pick_types(aw02.info, meg=False, eeg=True, eog=False, stim=False)  #読み込むチャンネルを設定
# Out:
# Extracting parameters from /Users/emi/Desktop/media_TBS/mod_tv/male02_tv_mod.set...
# /Users/emi/.pyenv/versions/anaconda2-4.2.0/lib/python2.7/site-packages/mne/utils.py:876: DeprecationWarning: Function read_events_eeglab is deprecated; read_events_eeglab is deprecated from 0.17 and will be removed in 0.18. Please use read_annotations and create events using events_from_annotations.
#   warnings.warn(msg, category=DeprecationWarning)
# 25 matching events found
# No baseline correction applied
# Not setting metadata
# 0 projection items activated
# Ready.
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.

# %%
#03
fname03 = data_path + cname + '03' + sname + hname

events03 = mne.io.read_events_eeglab('/Users/emi/Desktop/media_TBS/mod_tv/male03_tv_mod.set')
            
aw03 = mne.io.read_epochs_eeglab(fname03,montage=mon,
                               eog=('EOG1', 'EOG2'),
                               events=events03,
                               event_id = {'TV1':1, 'TV2':2, 'TV3':3, 'TV4':4, 'TV5':5, 'TV6':6, 'TV7':7, 'TV8':8, 'TV9':9, 'TV10':10, 'TV11':11, 'TV12':12, 'TV13':13, 'TV14':14, 'TV15':15, 'TV16':16, 'TV17':17, 'TV18':18, 'TV19':19, 'TV20':20, 'TV21':21,'TV22':22, 'TV23':23, 'TV24':24, 'TV25':25})
aw03.set_channel_types({'EOG1': 'eog', 'EOG2': 'eog'}) # Set Channel Type(それぞれを区別、名前をつける)
aw03.set_eeg_reference('average',projection=True)

picks03 = mne.pick_types(aw03.info, meg=False, eeg=True, eog=False, stim=False)  #読み込むチャンネルを設定
# Out:
# Extracting parameters from /Users/emi/Desktop/media_TBS/mod_tv/male03_tv_mod.set...
# /Users/emi/.pyenv/versions/anaconda2-4.2.0/lib/python2.7/site-packages/mne/utils.py:876: DeprecationWarning: Function read_events_eeglab is deprecated; read_events_eeglab is deprecated from 0.17 and will be removed in 0.18. Please use read_annotations and create events using events_from_annotations.
#   warnings.warn(msg, category=DeprecationWarning)
# 25 matching events found
# No baseline correction applied
# Not setting metadata
# 0 projection items activated
# Ready.
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.

# %%
#04
fname04 = data_path + cname + '04' + sname+ hname

events04 = mne.io.read_events_eeglab('/Users/emi/Desktop/media_TBS/mod_tv/male04_tv_mod.set')
            
aw04 = mne.io.read_epochs_eeglab(fname04,montage=mon,
                               eog=('EOG1', 'EOG2'),
                               events=events04,
                               event_id = {'TV1':1, 'TV2':2, 'TV3':3, 'TV4':4, 'TV5':5, 'TV6':6, 'TV7':7, 'TV8':8, 'TV9':9, 'TV10':10, 'TV11':11, 'TV12':12, 'TV13':13, 'TV14':14, 'TV15':15, 'TV16':16, 'TV17':17, 'TV18':18, 'TV19':19, 'TV20':20, 'TV21':21,'TV22':22, 'TV23':23, 'TV24':24, 'TV25':25})
aw04.set_channel_types({'EOG1': 'eog', 'EOG2': 'eog'}) # Set Channel Type(それぞれを区別、名前をつける)
aw04.set_eeg_reference('average',projection=True)

picks04 = mne.pick_types(aw04.info, meg=False, eeg=True, eog=False, stim=False)  #読み込むチャンネルを設定
# Out:
# Extracting parameters from /Users/emi/Desktop/media_TBS/mod_tv/male04_tv_mod.set...
# /Users/emi/.pyenv/versions/anaconda2-4.2.0/lib/python2.7/site-packages/mne/utils.py:876: DeprecationWarning: Function read_events_eeglab is deprecated; read_events_eeglab is deprecated from 0.17 and will be removed in 0.18. Please use read_annotations and create events using events_from_annotations.
#   warnings.warn(msg, category=DeprecationWarning)
# 25 matching events found
# No baseline correction applied
# Not setting metadata
# 0 projection items activated
# Ready.
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.

# %%
#05
fname05 = data_path + cname + '05' + sname + hname

events05 = mne.io.read_events_eeglab('/Users/emi/Desktop/media_TBS/mod_tv/male05_tv_mod.set')
            
aw05 = mne.io.read_epochs_eeglab(fname05,montage=mon,
                               eog=('EOG1', 'EOG2'),
                               events=events05,
                               event_id = {'TV1':1, 'TV2':2, 'TV3':3, 'TV4':4, 'TV5':5, 'TV6':6, 'TV7':7, 'TV8':8, 'TV9':9, 'TV10':10, 'TV11':11, 'TV12':12, 'TV13':13, 'TV14':14, 'TV15':15, 'TV16':16, 'TV17':17, 'TV18':18, 'TV19':19, 'TV20':20, 'TV21':21,'TV22':22, 'TV23':23, 'TV24':24, 'TV25':25})
aw05.set_channel_types({'EOG1': 'eog', 'EOG2': 'eog'}) # Set Channel Type(それぞれを区別、名前をつける)
aw05.set_eeg_reference('average',projection=True)

picks05 = mne.pick_types(aw05.info, meg=False, eeg=True, eog=False, stim=False)  #読み込むチャンネルを設定
# Out:
# Extracting parameters from /Users/emi/Desktop/media_TBS/mod_tv/male05_tv_mod.set...
# /Users/emi/.pyenv/versions/anaconda2-4.2.0/lib/python2.7/site-packages/mne/utils.py:876: DeprecationWarning: Function read_events_eeglab is deprecated; read_events_eeglab is deprecated from 0.17 and will be removed in 0.18. Please use read_annotations and create events using events_from_annotations.
#   warnings.warn(msg, category=DeprecationWarning)
# 25 matching events found
# No baseline correction applied
# Not setting metadata
# 0 projection items activated
# Ready.
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.

# %%
#06
fname06 = data_path + cname + '06' + sname + hname

events06 = mne.io.read_events_eeglab('/Users/emi/Desktop/media_TBS/mod_tv/male06_tv_mod.set')
            
aw06 = mne.io.read_epochs_eeglab(fname06,montage=mon,
                               eog=('EOG1', 'EOG2'),
                               events=events06,
                               event_id = {'TV1':1, 'TV2':2, 'TV3':3, 'TV4':4, 'TV5':5, 'TV6':6, 'TV7':7, 'TV8':8, 'TV9':9, 'TV10':10, 'TV11':11, 'TV12':12, 'TV13':13, 'TV14':14, 'TV15':15, 'TV16':16, 'TV17':17, 'TV18':18, 'TV19':19, 'TV20':20, 'TV21':21,'TV22':22, 'TV23':23, 'TV24':24, 'TV25':25})
aw06.set_channel_types({'EOG1': 'eog', 'EOG2': 'eog'}) # Set Channel Type(それぞれを区別、名前をつける)
aw06.set_eeg_reference('average',projection=True)

picks06 = mne.pick_types(aw06.info, meg=False, eeg=True, eog=False, stim=False)  #読み込むチャンネルを設定
# Out:
# Extracting parameters from /Users/emi/Desktop/media_TBS/mod_tv/male06_tv_mod.set...
# /Users/emi/.pyenv/versions/anaconda2-4.2.0/lib/python2.7/site-packages/mne/utils.py:876: DeprecationWarning: Function read_events_eeglab is deprecated; read_events_eeglab is deprecated from 0.17 and will be removed in 0.18. Please use read_annotations and create events using events_from_annotations.
#   warnings.warn(msg, category=DeprecationWarning)
# 25 matching events found
# No baseline correction applied
# Not setting metadata
# 0 projection items activated
# Ready.
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.

# %%
#07
fname07 = data_path + cname + '07' + sname + hname

events07 = mne.io.read_events_eeglab('/Users/emi/Desktop/media_TBS/mod_tv/male07_tv_mod.set')
            
aw07 = mne.io.read_epochs_eeglab(fname07,montage=mon,
                               eog=('EOG1', 'EOG2'),
                               events=events07,
                               event_id = {'TV1':1, 'TV2':2, 'TV3':3, 'TV4':4, 'TV5':5, 'TV6':6, 'TV7':7, 'TV8':8, 'TV9':9, 'TV10':10, 'TV11':11, 'TV12':12, 'TV13':13, 'TV14':14, 'TV15':15, 'TV16':16, 'TV17':17, 'TV18':18, 'TV19':19, 'TV20':20, 'TV21':21,'TV22':22, 'TV23':23, 'TV24':24, 'TV25':25})
aw07.set_channel_types({'EOG1': 'eog', 'EOG2': 'eog'}) # Set Channel Type(それぞれを区別、名前をつける)
aw07.set_eeg_reference('average',projection=True)

picks07 = mne.pick_types(aw07.info, meg=False, eeg=True, eog=False, stim=False)  #読み込むチャンネルを設定
# Out:
# Extracting parameters from /Users/emi/Desktop/media_TBS/mod_tv/male07_tv_mod.set...
# /Users/emi/.pyenv/versions/anaconda2-4.2.0/lib/python2.7/site-packages/mne/utils.py:876: DeprecationWarning: Function read_events_eeglab is deprecated; read_events_eeglab is deprecated from 0.17 and will be removed in 0.18. Please use read_annotations and create events using events_from_annotations.
#   warnings.warn(msg, category=DeprecationWarning)
# 25 matching events found
# No baseline correction applied
# Not setting metadata
# 0 projection items activated
# Ready.
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.

# %%
#08
fname08 = data_path + cname + '08' + sname + hname

events08 = mne.io.read_events_eeglab('/Users/emi/Desktop/media_TBS/mod_tv/male08_tv_mod.set')
            
aw08 = mne.io.read_epochs_eeglab(fname08,montage=mon,
                               eog=('EOG1', 'EOG2'),
                               events=events08,
                               event_id = {'TV1':1, 'TV2':2, 'TV3':3, 'TV4':4, 'TV5':5, 'TV6':6, 'TV7':7, 'TV8':8, 'TV9':9, 'TV10':10, 'TV11':11, 'TV12':12, 'TV13':13, 'TV14':14, 'TV15':15, 'TV16':16, 'TV17':17, 'TV18':18, 'TV19':19, 'TV20':20, 'TV21':21,'TV22':22, 'TV23':23, 'TV24':24, 'TV25':25})
aw08.set_channel_types({'EOG1': 'eog', 'EOG2': 'eog'}) # Set Channel Type(それぞれを区別、名前をつける)
aw08.set_eeg_reference('average',projection=True)

picks08 = mne.pick_types(aw08.info, meg=False, eeg=True, eog=False, stim=False)  #読み込むチャンネルを設定
# Out:
# Extracting parameters from /Users/emi/Desktop/media_TBS/mod_tv/male08_tv_mod.set...
# /Users/emi/.pyenv/versions/anaconda2-4.2.0/lib/python2.7/site-packages/mne/utils.py:876: DeprecationWarning: Function read_events_eeglab is deprecated; read_events_eeglab is deprecated from 0.17 and will be removed in 0.18. Please use read_annotations and create events using events_from_annotations.
#   warnings.warn(msg, category=DeprecationWarning)
# 25 matching events found
# No baseline correction applied
# Not setting metadata
# 0 projection items activated
# Ready.
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.

# %%
#09
fname09 = data_path + cname + '09' + sname + hname

events09 = mne.io.read_events_eeglab('/Users/emi/Desktop/media_TBS/mod_tv/male09_tv_mod.set')
            
aw09 = mne.io.read_epochs_eeglab(fname09,montage=mon,
                               eog=('EOG1', 'EOG2'),
                               events=events09,
                               event_id = {'TV1':1, 'TV2':2, 'TV3':3, 'TV4':4, 'TV5':5, 'TV6':6, 'TV7':7, 'TV8':8, 'TV9':9, 'TV10':10, 'TV11':11, 'TV12':12, 'TV13':13, 'TV14':14, 'TV15':15, 'TV16':16, 'TV17':17, 'TV18':18, 'TV19':19, 'TV20':20, 'TV21':21,'TV22':22, 'TV23':23, 'TV24':24, 'TV25':25})
aw09.set_channel_types({'EOG1': 'eog', 'EOG2': 'eog'}) # Set Channel Type(それぞれを区別、名前をつける)
aw09.set_eeg_reference('average',projection=True)

picks09 = mne.pick_types(aw09.info, meg=False, eeg=True, eog=False, stim=False)  #読み込むチャンネルを設定
# Out:
# Extracting parameters from /Users/emi/Desktop/media_TBS/mod_tv/male09_tv_mod.set...
# /Users/emi/.pyenv/versions/anaconda2-4.2.0/lib/python2.7/site-packages/mne/utils.py:876: DeprecationWarning: Function read_events_eeglab is deprecated; read_events_eeglab is deprecated from 0.17 and will be removed in 0.18. Please use read_annotations and create events using events_from_annotations.
#   warnings.warn(msg, category=DeprecationWarning)
# 25 matching events found
# No baseline correction applied
# Not setting metadata
# 0 projection items activated
# Ready.
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.

# %%
#10
fname10 = data_path + cname + '10' + sname + hname

events10 = mne.io.read_events_eeglab('/Users/emi/Desktop/media_TBS/mod_tv/male10_tv_mod.set')
            
aw10 = mne.io.read_epochs_eeglab(fname10,montage=mon,
                               eog=('EOG1', 'EOG2'),
                               events=events10,
                               event_id = {'TV1':1, 'TV2':2, 'TV3':3, 'TV4':4, 'TV5':5, 'TV6':6, 'TV7':7, 'TV8':8, 'TV9':9, 'TV10':10, 'TV11':11, 'TV12':12, 'TV13':13, 'TV14':14, 'TV15':15, 'TV16':16, 'TV17':17, 'TV18':18, 'TV19':19, 'TV20':20, 'TV21':21,'TV22':22, 'TV23':23, 'TV24':24, 'TV25':25})
aw10.set_channel_types({'EOG1': 'eog', 'EOG2': 'eog'}) # Set Channel Type(それぞれを区別、名前をつける)
aw10.set_eeg_reference('average',projection=True)

picks10 = mne.pick_types(aw10.info, meg=False, eeg=True, eog=False, stim=False)  #読み込むチャンネルを設定
# Out:
# Extracting parameters from /Users/emi/Desktop/media_TBS/mod_tv/male10_tv_mod.set...
# /Users/emi/.pyenv/versions/anaconda2-4.2.0/lib/python2.7/site-packages/mne/utils.py:876: DeprecationWarning: Function read_events_eeglab is deprecated; read_events_eeglab is deprecated from 0.17 and will be removed in 0.18. Please use read_annotations and create events using events_from_annotations.
#   warnings.warn(msg, category=DeprecationWarning)
# 25 matching events found
# No baseline correction applied
# Not setting metadata
# 0 projection items activated
# Ready.
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.

# %%
#11
fname11 = data_path + cname + '11' + sname + hname

events11 = mne.io.read_events_eeglab('/Users/emi/Desktop/media_TBS/mod_tv/male11_tv_mod.set')
            
aw11 = mne.io.read_epochs_eeglab(fname11,montage=mon,
                               eog=('EOG1', 'EOG2'),
                               events=events11,
                               event_id = {'TV1':1, 'TV2':2, 'TV3':3, 'TV4':4, 'TV5':5, 'TV6':6, 'TV7':7, 'TV8':8, 'TV9':9, 'TV10':10, 'TV11':11, 'TV12':12, 'TV13':13, 'TV14':14, 'TV15':15, 'TV16':16, 'TV17':17, 'TV18':18, 'TV19':19, 'TV20':20, 'TV21':21,'TV22':22, 'TV23':23, 'TV24':24, 'TV25':25})
aw11.set_channel_types({'EOG1': 'eog', 'EOG2': 'eog'}) # Set Channel Type(それぞれを区別、名前をつける)
aw11.set_eeg_reference('average',projection=True)

picks11 = mne.pick_types(aw11.info, meg=False, eeg=True, eog=False, stim=False)  #読み込むチャンネルを設定


#12
fname12 = data_path + cname + '12' + sname + hname

events12 = mne.io.read_events_eeglab('/Users/emi/Desktop/media_TBS/mod_tv/male12_tv_mod.set')

aw12 = mne.io.read_epochs_eeglab(fname12,montage=mon,
                               eog=('EOG1', 'EOG2'),
                               events=events11,
                               event_id = {'TV1':1, 'TV2':2, 'TV3':3, 'TV4':4, 'TV5':5, 'TV6':6, 'TV7':7, 'TV8':8, 'TV9':9, 'TV10':10, 'TV11':11, 'TV12':12, 'TV13':13, 'TV14':14, 'TV15':15, 'TV16':16, 'TV17':17, 'TV18':18, 'TV19':19, 'TV20':20, 'TV21':21,'TV22':22, 'TV23':23, 'TV24':24, 'TV25':25})
aw12.set_channel_types({'EOG1': 'eog', 'EOG2': 'eog'}) # Set Channel Type(それぞれを区別、名前をつける)
aw12.set_eeg_reference('average',projection=True)
# Out:
# Extracting parameters from /Users/emi/Desktop/media_TBS/mod_tv/male11_tv_mod.set...
# /Users/emi/.pyenv/versions/anaconda2-4.2.0/lib/python2.7/site-packages/mne/utils.py:876: DeprecationWarning: Function read_events_eeglab is deprecated; read_events_eeglab is deprecated from 0.17 and will be removed in 0.18. Please use read_annotations and create events using events_from_annotations.
#   warnings.warn(msg, category=DeprecationWarning)
# 25 matching events found
# No baseline correction applied
# Not setting metadata
# 0 projection items activated
# Ready.
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Extracting parameters from /Users/emi/Desktop/media_TBS/mod_tv/male12_tv_mod.set...
# ...

# %%
aw = mne.concatenate_epochs([aw01, aw02, aw03, aw04, aw05, aw06, aw07, aw08, aw09, aw10, aw11, aw12])

fig = aw.plot_psd_topomap(ch_type='eeg', normalize=True) #normalizeで決まった周波数帯で出てくる、topomapが顔の図
# Out:
# 300 matching events found
# No baseline correction applied
# Not setting metadata
# Created an SSP operator (subspace dimension = 1)
# 0 bad epochs dropped
#     Using multitaper spectrum estimation with 7 DPSS windows
